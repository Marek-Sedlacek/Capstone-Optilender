# %% [markdown]
# ## Regressions

# %% [markdown]
# In this code I run the regression:
#     simple_return ~ age_in_months + borrower_rate + payment + C(term) + %s
#
# Where %s is replaced iteratively by the other variables. I generate the file simple_regressions.csv, which records the variable substituted, the pvalue, rsquared, confidence interval low (2.5%), and confidence interval high (97.5%).

# %%
import random
import os
import copy
import pickle as pk
from collections import Counter
import itertools as it
import sqlalchemy as sql
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf
import statsmodels.api as sm

# %% [markdown]
# #### DB Connection

# %%
creds   = '<creds>'
ip      = '127.0.0.1'
port    = 5432
dbase   = 'p2p_lending'
constring = 'postgresql://%s@%s:%d/%s' %(creds, ip, port, dbase)
eng = sql.create_engine(constring)
con = eng.connect()

# %% [markdown]
# #### Check number of unique values in each column

# %%
#get unique values for each column 
cols = pd.read_sql('select * from merged_train limit 1', con=eng).columns

# %%
cols = cols.difference([c for c in cols if 'date' in c] + ['member_key','loan_number','listing_number',
                                                           'amount_funded','borrower_rate','late_fees_paid',
                                                           'principal_balance','service_fees_paid',
                                                           'interest_paid', 'principal_paid','simple_return',
                                                           'next_payment_due_amount','prosper_rating'])

# %%
unique_counts = pd.Series()

# %%
for i,col in enumerate(cols):
    stmt = ('with outpt as (select distinct %s from merged_train) ' %col +
            'select count(*) from outpt')
    cur = con.execute(stmt)
    val = cur.fetchone()[0]
    unique_counts[col] = val
    print '%d %s: ' %(i,col), val
# Out:
# 0 age_in_months:  106
# 1 ale001:  36
# 2 ale002:  37
# 3 ale005:  36
# 4 ale007:  8
# 5 ale022:  11
# 6 ale023:  14
# 7 ale026:  8
# 8 ale071:  36
# 9 ale074:  7
# 10 ale075:  10
# 11 ale076:  7
# 12 ale077:  5
# 13 ale078:  10
# 14 ale080:  4
# 15 ale081:  10
# 16 ale084:  10
# 17 ale403:  127
# 18 ale501:  11
# 19 ale502:  10
# 20 ale503:  11
# 21 ale601:  10
# 22 ale720:  87
# 23 ale724:  86
# 24 ale740:  86
# 25 ale801:  12
# 26 ale804:  8
# 27 ale901:  52
# 28 ale903:  51
# 29 ale904:  46
# 30 ale905:  44
# 31 ale906:  44
# 32 ale908:  51
# 33 all001:  111
# 34 all002:  116
# 35 all003:  61
# 36 all005:  104
# 37 all006:  56
# 38 all007:  61
# 39 all010:  59
# 40 all021:  20
# 41 all022:  32
# 42 all023:  42
# 43 all024:  63
# 44 all026:  57
# 45 all051:  19
# 46 all052:  9
# 47 all062:  61
# 48 all064:  19
# 49 all067:  19
# 50 all071:  103
# 51 all074:  17
# 52 all075:  36
# 53 all076:  20
# 54 all077:  14
# 55 all078:  35
# 56 all080:  23
# 57 all081:  36
# 58 all082:  17
# 59 all084:  35
# 60 all085:  17
# 61 all086:  20
# 62 all090:  30
# 63 all091:  30
# 64 all092:  30
# 65 all101:  59
# 66 all102:  63
# 67 all103:  10
# 68 all104:  17
# 69 all105:  11
# 70 all106:  19
# 71 all107:  10
# 72 all108:  13
# 73 all109:  16
# 74 all110:  6
# 75 all111:  8
# 76 all112:  7
# 77 all113:  10
# 78 all114:  17
# 79 all115:  19
# 80 all116:  12
# 81 all117:  13
# 82 all118:  17
# 83 all119:  10
# 84 all121:  9
# 85 all122:  19
# 86 all123:  11
# 87 all124:  17
# 88 all125:  19
# 89 all126:  68
# 90 all127:  27
# 91 all128:  27
# 92 all129:  27
# 93 all130:  26
# 94 all131:  27
# 95 all134:  16
# 96 all136:  24
# 97 all141:  26
# 98 all142:  8
# 99 all143:  24
# 100 all144:  10
# 101 all145:  22
# 102 all146:  7
# 103 all151:  40
# 104 all152:  24
# 105 all153:  33
# 106 all155:  40
# 107 all156:  32
# 108 all201:  153738
# 109 all202:  47477
# 110 all207:  5700
# 111 all208:  8410
# 112 all301:  138217
# 113 all403:  171
# 114 all501:  10
# 115 all502:  10
# 116 all503:  10
# 117 all504:  11
# 118 all505:  11
# 119 all524:  119
# 120 all601:  9
# 121 all602:  10
# 122 all701:  600
# 123 all702:  140
# 124 all703:  275
# 125 all720:  87
# 126 all724:  87
# 127 all740:  87
# 128 all760:  93
# 129 all780:  121
# 130 all790:  94
# 131 all801:  44
# 132 all803:  12
# 133 all804:  26
# 134 all805:  28
# 135 all806:  26
# 136 all807:  26
# 137 all901:  92
# 138 all903:  86
# 139 all904:  79
# 140 all905:  79
# 141 all906:  78
# 142 all907:  98
# 143 amount_borrowed:  4710
# 144 amount_delinquent:  9462
# 145 amount_remaining:  185
# 146 analysis_class:  1
# 147 aut001:  36
# 148 aut071:  36
# 149 aut720:  87
# 150 bac001:  67
# 151 bac002:  66
# 152 bac005:  67
# 153 bac007:  39
# 154 bac022:  17
# 155 bac023:  25
# 156 bac026:  36
# 157 bac028:  36
# 158 bac031:  31
# 159 bac035:  23
# 160 bac037:  16
# 161 bac042:  27
# 162 bac044:  21
# 163 bac045:  12
# 164 bac071:  65
# 165 bac074:  12
# 166 bac075:  25
# 167 bac076:  16
# 168 bac077:  10
# 169 bac078:  25
# 170 bac080:  11
# 171 bac081:  24
# 172 bac084:  24
# 173 bac159:  34
# 174 bac302:  15550
# 175 bac303:  4679
# 176 bac401:  47916
# 177 bac403:  152
# 178 bac501:  11
# 179 bac502:  11
# 180 bac503:  11
# 181 bac550:  377
# 182 bac584:  29
# 183 bac589:  29
# 184 bac601:  10
# 185 bac751:  15
# 186 bac752:  27
# 187 bac801:  29
# 188 bac804:  20
# 189 bac901:  82
# 190 bac903:  84
# 191 bac904:  83
# 192 bac905:  82
# 193 bac906:  82
# 194 bac908:  97
# 195 bankcard_utilization:  152
# 196 bnk001:  55
# 197 bnk026:  17
# 198 borrower_apr:  5422
# 199 borrower_city:  21827
# 200 borrower_state:  52
# 201 brr026:  47
# 202 cap026:  8
# 203 cap801:  11
# 204 credit_lines_last7_years:  118
# 205 cru001:  52
# 206 current_credit_lines:  61
# 207 current_delinquencies:  31
# 208 days_past_due:  2600
# 209 debt_sale_proceeds_received:  42
# 210 delinquencies_last7_years:  101
# 211 delinquencies_over30_days:  101
# 212 delinquencies_over60_days:  77
# 213 delinquencies_over90_days:  101
# 214 dti_wprosper_loan:  356
# 215 effective_yield:  2826
# 216 employment_status_description:  9
# 217 estimated_loss_rate:  128
# 218 estimated_return:  3367
# 219 fico_score:  14
# 220 fil001:  46
# 221 fil022:  11
# 222 fil023:  15
# 223 fin001:  47
# 224 fin026:  11
# 225 fin601:  10
# 226 fin801:  19
# 227 first_recorded_credit_line:  14691
# 228 funding_threshold:  3
# 229 heq001:  13
# 230 iln001:  66
# 231 iln002:  86
# 232 iln005:  66
# 233 iln006:  36
# 234 iln007:  36
# 235 iln022:  13
# 236 iln023:  21
# 237 iln026:  36
# 238 iln064:  10
# 239 iln067:  10
# 240 iln071:  67
# 241 iln074:  10
# 242 iln075:  26
# 243 iln076:  14
# 244 iln077:  12
# 245 iln078:  25
# 246 iln080:  23
# 247 iln081:  25
# 248 iln084:  20
# 249 iln085:  7
# 250 iln086:  9
# 251 iln101:  39
# 252 iln102:  39
# 253 iln103:  7
# 254 iln104:  12
# 255 iln105:  8
# 256 iln106:  14
# 257 iln107:  8
# 258 iln108:  9
# 259 iln109:  10
# 260 iln110:  6
# 261 iln111:  8
# 262 iln112:  6
# 263 iln113:  9
# 264 iln114:  10
# 265 iln115:  12
# 266 iln116:  10
# 267 iln117:  8
# 268 iln118:  10
# 269 iln119:  10
# 270 iln122:  18
# 271 iln124:  11
# 272 iln125:  13
# 273 iln126:  41
# 274 iln127:  20
# 275 iln128:  19
# 276 iln129:  19
# 277 iln130:  11
# 278 iln201:  68595
# 279 iln301:  72482
# 280 iln302:  40148
# 281 iln403:  217
# 282 iln501:  11
# 283 iln502:  11
# 284 iln503:  11
# 285 iln504:  11
# 286 iln601:  10
# 287 iln701:  521
# 288 iln702:  337
# 289 iln703:  355
# 290 iln720:  87
# 291 iln724:  86
# 292 iln740:  86
# 293 iln801:  26
# 294 iln804:  16
# 295 iln901:  89
# 296 iln903:  89
# 297 iln904:  90
# 298 iln905:  86
# 299 iln906:  75
# 300 iln908:  97
# 301 iln914:  98
# 302 income_range:  9
# 303 income_range_description:  9
# 304 income_verifiable:  3
# 305 inquiries_last6_months:  38
# 306 installment_balance:  75750
# 307 investment_type_description:  3
# 308 investment_typeid:  4
# 309 is_homeowner:  3
# 310 lender_indicator:  3
# 311 lender_yield:  1872
# 312 lfi801:  15
# 313 listing_category_id:  23
# 314 listing_monthly_payment:  32906
# 315 listing_status:  2
# 316 listing_status_reason:  2
# 317 loan_default_reason:  7
# 318 loan_default_reason_description:  7
# 319 loan_status:  5
# 320 loan_status_description:  5
# 321 max_prior_prosper_loan:  1021
# 322 min_prior_prosper_loan:  972
# 323 monthly_debt:  5012
# 324 months_employed:  833
# 325 now_delinquent_derog:  31
# 326 occupation:  68
# 327 open_credit_lines:  57
# 328 partial_funding_indicator:  3
# 329 payment:  45809
# 330 percent_funded:  159
# 331 prior_prosper_loan_earliest_pay_off:  48
# 332 prior_prosper_loans:  12
# 333 prior_prosper_loans_active:  5
# 334 prior_prosper_loans_balance_outstanding:  26265
# 335 prior_prosper_loans_cycles_billed:  144
# 336 prior_prosper_loans_late_cycles:  47
# 337 prior_prosper_loans_late_payments_one_month_plus:  20
# 338 prior_prosper_loans_ontime_payments:  143
# 339 prior_prosper_loans_principal_borrowed:  1747
# 340 prior_prosper_loans_principal_outstanding:  25637
# 341 prosper_fees_paid:  66
# 342 prosper_rating:  7
# 343 prosper_score:  12
# 344 public_records_last10_years:  26
# 345 public_records_last12_months:  8
# 346 real_estate_balance:  99150
# 347 real_estate_payment:  6080
# 348 ref001:  33
# 349 rep001:  30
# 350 rep002:  48
# 351 rep005:  30
# 352 rep026:  18
# 353 rep071:  28
# 354 rep074:  8
# 355 rep075:  16
# 356 rep076:  9
# 357 rep077:  6
# 358 rep078:  16
# 359 rep080:  6
# 360 rep081:  16
# 361 rep084:  16
# 362 rep302:  44568
# 363 rep501:  11
# 364 rep503:  11
# 365 rep601:  10
# 366 rep901:  63
# 367 rep903:  62
# 368 rep904:  56
# 369 rep905:  56
# 370 rep906:  61
# 371 rep908:  69
# 372 rev001:  89
# 373 rev002:  89
# 374 rev005:  89
# 375 rev006:  53
# 376 rev007:  55
# 377 rev022:  29
# 378 rev023:  39
# 379 rev024:  57
# 380 rev026:  53
# 381 rev028:  50
# 382 rev038:  45
# 383 rev044:  23
# 384 rev064:  12
# 385 rev067:  12
# 386 rev071:  85
# 387 rev074:  16
# 388 rev075:  28
# 389 rev076:  18
# 390 rev077:  11
# 391 rev078:  28
# 392 rev080:  12
# 393 rev081:  28
# 394 rev084:  28
# 395 rev085:  11
# 396 rev086:  15
# 397 rev101:  56
# 398 rev102:  57
# 399 rev103:  7
# 400 rev104:  13
# 401 rev105:  10
# 402 rev106:  17
# 403 rev107:  9
# 404 rev108:  12
# 405 rev109:  14
# 406 rev110:  5
# 407 rev111:  6
# 408 rev112:  5
# 409 rev113:  7
# 410 rev114:  13
# 411 rev115:  15
# 412 rev116:  8
# 413 rev117:  13
# 414 rev118:  11
# 415 rev119:  8
# 416 rev122:  10
# 417 rev124:  13
# 418 rev125:  16
# 419 rev126:  61
# 420 rev127:  23
# 421 rev128:  23
# 422 rev129:  23
# 423 rev130:  23
# 424 rev159:  46
# 425 rev201:  53499
# 426 rev202:  13638
# 427 rev301:  28883
# 428 rev302:  15560
# 429 rev401:  52288
# 430 rev403:  127
# 431 rev404:  137
# 432 rev501:  11
# 433 rev502:  11
# 434 rev503:  11
# 435 rev504:  11
# 436 rev524:  99
# 437 rev550:  462
# 438 rev584:  29
# 439 rev585:  53
# 440 rev589:  29
# 441 rev590:  53
# 442 rev601:  10
# 443 rev701:  601
# 444 rev702:  196
# 445 rev703:  324
# 446 rev720:  87
# 447 rev724:  87
# 448 rev740:  87
# 449 rev751:  15
# 450 rev752:  27
# 451 rev901:  86
# 452 rev903:  86
# 453 rev904:  80
# 454 rev905:  80
# 455 rev906:  80
# 456 rev908:  96
# 457 revolving_available_percent:  102
# 458 revolving_balance:  56945
# 459 rti026:  6
# 460 rtl001:  47
# 461 rtl002:  53
# 462 rtl005:  47
# 463 rtl026:  29
# 464 rtl071:  46
# 465 rtl074:  12
# 466 rtl075:  15
# 467 rtl076:  13
# 468 rtl077:  7
# 469 rtl078:  15
# 470 rtl080:  8
# 471 rtl081:  15
# 472 rtl084:  15
# 473 rtl501:  11
# 474 rtl502:  11
# 475 rtl503:  11
# 476 rtl901:  73
# 477 rtl903:  74
# 478 rtl904:  72
# 479 rtl905:  71
# 480 rtl906:  69
# 481 rtl908:  91
# 482 rtr001:  47
# 483 rtr002:  52
# 484 rtr005:  47
# 485 rtr007:  34
# 486 rtr022:  23
# 487 rtr023:  27
# 488 rtr026:  29
# 489 rtr028:  28
# 490 rtr031:  23
# 491 rtr035:  15
# 492 rtr044:  11
# 493 rtr071:  46
# 494 rtr074:  12
# 495 rtr075:  15
# 496 rtr076:  13
# 497 rtr077:  7
# 498 rtr078:  15
# 499 rtr080:  8
# 500 rtr081:  15
# 501 rtr084:  15
# 502 rtr159:  26
# 503 rtr303:  1993
# 504 rtr401:  19534
# 505 rtr403:  162
# 506 rtr501:  11
# 507 rtr584:  29
# 508 rtr585:  53
# 509 rtr589:  29
# 510 rtr590:  53
# 511 rtr601:  9
# 512 rtr751:  15
# 513 rtr752:  27
# 514 rtr901:  72
# 515 rtr903:  73
# 516 rtr904:  72
# 517 rtr905:  71
# 518 rtr906:  69
# 519 rtr908:  91
# 520 satisfactory_accounts:  121
# 521 scorex:  12
# 522 scorex_change:  16
# 523 stated_monthly_income:  23855
# 524 term:  3
# 525 total_inquiries:  76
# 526 total_open_revolving_accounts:  56
# 527 total_trade_items:  119
# 528 was_delinquent_derog:  38

# %%
pd.options.display.max_rows = 550
unique_counts.sort_index()
# Out:
# age_in_months                                          106
# ale001                                                  36
# ale002                                                  37
# ale005                                                  36
# ale007                                                   8
# ale022                                                  11
# ale023                                                  14
# ale026                                                   8
# ale071                                                  36
# ale074                                                   7
# ale075                                                  10
# ale076                                                   7
# ale077                                                   5
# ale078                                                  10
# ale080                                                   4
# ale081                                                  10
# ale084                                                  10
# ale403                                                 127
# ale501                                                  11
# ale502                                                  10
# ale503                                                  11
# ale601                                                  10
# ale720                                                  87
# ale724                                                  86
# ale740                                                  86
# ale801                                                  12
# ale804                                                   8
# ale901                                                  52
# ale903                                                  51
# ale904                                                  46
# ale905                                                  44
# ale906                                                  44
# ale908                                                  51
# all001                                                 111
# all002                                                 116
# all003                                                  61
# all005                                                 104
# all006                                                  56
# all007                                                  61
# all010                                                  59
# all021                                                  20
# all022                                                  32
# all023                                                  42
# all024                                                  63
# all026                                                  57
# all051                                                  19
# all052                                                   9
# all062                                                  61
# all064                                                  19
# all067                                                  19
# all071                                                 103
# all074                                                  17
# all075                                                  36
# all076                                                  20
# all077                                                  14
# all078                                                  35
# all080                                                  23
# all081                                                  36
# all082                                                  17
# all084                                                  35
# all085                                                  17
# all086                                                  20
# all090                                                  30
# all091                                                  30
# all092                                                  30
# all101                                                  59
# all102                                                  63
# all103                                                  10
# all104                                                  17
# all105                                                  11
# all106                                                  19
# all107                                                  10
# all108                                                  13
# all109                                                  16
# all110                                                   6
# all111                                                   8
# all112                                                   7
# all113                                                  10
# all114                                                  17
# all115                                                  19
# all116                                                  12
# all117                                                  13
# all118                                                  17
# all119                                                  10
# all121                                                   9
# all122                                                  19
# all123                                                  11
# all124                                                  17
# all125                                                  19
# all126                                                  68
# all127                                                  27
# all128                                                  27
# all129                                                  27
# all130                                                  26
# all131                                                  27
# all134                                                  16
# all136                                                  24
# all141                                                  26
# all142                                                   8
# all143                                                  24
# all144                                                  10
# all145                                                  22
# all146                                                   7
# all151                                                  40
# all152                                                  24
# all153                                                  33
# all155                                                  40
# all156                                                  32
# all201                                              153738
# all202                                               47477
# all207                                                5700
# all208                                                8410
# all301                                              138217
# all403                                                 171
# all501                                                  10
# all502                                                  10
# all503                                                  10
# all504                                                  11
# all505                                                  11
# all524                                                 119
# all601                                                   9
# all602                                                  10
# all701                                                 600
# all702                                                 140
# all703                                                 275
# all720                                                  87
# all724                                                  87
# all740                                                  87
# all760                                                  93
# all780                                                 121
# all790                                                  94
# all801                                                  44
# all803                                                  12
# all804                                                  26
# all805                                                  28
# all806                                                  26
# all807                                                  26
# all901                                                  92
# all903                                                  86
# all904                                                  79
# all905                                                  79
# all906                                                  78
# all907                                                  98
# amount_borrowed                                       4710
# amount_delinquent                                     9462
# amount_remaining                                       185
# analysis_class                                           1
# aut001                                                  36
# aut071                                                  36
# aut720                                                  87
# bac001                                                  67
# bac002                                                  66
# bac005                                                  67
# bac007                                                  39
# bac022                                                  17
# bac023                                                  25
# bac026                                                  36
# bac028                                                  36
# bac031                                                  31
# bac035                                                  23
# bac037                                                  16
# bac042                                                  27
# bac044                                                  21
# bac045                                                  12
# bac071                                                  65
# bac074                                                  12
# bac075                                                  25
# bac076                                                  16
# bac077                                                  10
# bac078                                                  25
# bac080                                                  11
# bac081                                                  24
# bac084                                                  24
# bac159                                                  34
# bac302                                               15550
# bac303                                                4679
# bac401                                               47916
# bac403                                                 152
# bac501                                                  11
# bac502                                                  11
# bac503                                                  11
# bac550                                                 377
# bac584                                                  29
# bac589                                                  29
# bac601                                                  10
# bac751                                                  15
# bac752                                                  27
# bac801                                                  29
# bac804                                                  20
# bac901                                                  82
# bac903                                                  84
# bac904                                                  83
# bac905                                                  82
# bac906                                                  82
# bac908                                                  97
# bankcard_utilization                                   152
# bnk001                                                  55
# bnk026                                                  17
# borrower_apr                                          5422
# borrower_city                                        21827
# borrower_state                                          52
# brr026                                                  47
# cap026                                                   8
# cap801                                                  11
# credit_lines_last7_years                               118
# cru001                                                  52
# current_credit_lines                                    61
# current_delinquencies                                   31
# days_past_due                                         2600
# debt_sale_proceeds_received                             42
# delinquencies_last7_years                              101
# delinquencies_over30_days                              101
# delinquencies_over60_days                               77
# delinquencies_over90_days                              101
# dti_wprosper_loan                                      356
# effective_yield                                       2826
# employment_status_description                            9
# estimated_loss_rate                                    128
# estimated_return                                      3367
# fico_score                                              14
# fil001                                                  46
# fil022                                                  11
# fil023                                                  15
# fin001                                                  47
# fin026                                                  11
# fin601                                                  10
# fin801                                                  19
# first_recorded_credit_line                           14691
# funding_threshold                                        3
# heq001                                                  13
# iln001                                                  66
# iln002                                                  86
# iln005                                                  66
# iln006                                                  36
# iln007                                                  36
# iln022                                                  13
# iln023                                                  21
# iln026                                                  36
# iln064                                                  10
# iln067                                                  10
# iln071                                                  67
# iln074                                                  10
# iln075                                                  26
# iln076                                                  14
# iln077                                                  12
# iln078                                                  25
# iln080                                                  23
# iln081                                                  25
# iln084                                                  20
# iln085                                                   7
# iln086                                                   9
# iln101                                                  39
# iln102                                                  39
# iln103                                                   7
# iln104                                                  12
# iln105                                                   8
# iln106                                                  14
# iln107                                                   8
# iln108                                                   9
# iln109                                                  10
# iln110                                                   6
# iln111                                                   8
# iln112                                                   6
# iln113                                                   9
# iln114                                                  10
# iln115                                                  12
# iln116                                                  10
# iln117                                                   8
# iln118                                                  10
# iln119                                                  10
# iln122                                                  18
# iln124                                                  11
# iln125                                                  13
# iln126                                                  41
# iln127                                                  20
# iln128                                                  19
# iln129                                                  19
# iln130                                                  11
# iln201                                               68595
# iln301                                               72482
# iln302                                               40148
# iln403                                                 217
# iln501                                                  11
# iln502                                                  11
# iln503                                                  11
# iln504                                                  11
# iln601                                                  10
# iln701                                                 521
# iln702                                                 337
# iln703                                                 355
# iln720                                                  87
# iln724                                                  86
# iln740                                                  86
# iln801                                                  26
# iln804                                                  16
# iln901                                                  89
# iln903                                                  89
# iln904                                                  90
# iln905                                                  86
# iln906                                                  75
# iln908                                                  97
# iln914                                                  98
# income_range                                             9
# income_range_description                                 9
# income_verifiable                                        3
# inquiries_last6_months                                  38
# installment_balance                                  75750
# investment_type_description                              3
# investment_typeid                                        4
# is_homeowner                                             3
# lender_indicator                                         3
# lender_yield                                          1872
# lfi801                                                  15
# listing_category_id                                     23
# listing_monthly_payment                              32906
# listing_status                                           2
# listing_status_reason                                    2
# loan_default_reason                                      7
# loan_default_reason_description                          7
# loan_status                                              5
# loan_status_description                                  5
# max_prior_prosper_loan                                1021
# min_prior_prosper_loan                                 972
# monthly_debt                                          5012
# months_employed                                        833
# now_delinquent_derog                                    31
# occupation                                              68
# open_credit_lines                                       57
# partial_funding_indicator                                3
# payment                                              45809
# percent_funded                                         159
# prior_prosper_loan_earliest_pay_off                     48
# prior_prosper_loans                                     12
# prior_prosper_loans_active                               5
# prior_prosper_loans_balance_outstanding              26265
# prior_prosper_loans_cycles_billed                      144
# prior_prosper_loans_late_cycles                         47
# prior_prosper_loans_late_payments_one_month_plus        20
# prior_prosper_loans_ontime_payments                    143
# prior_prosper_loans_principal_borrowed                1747
# prior_prosper_loans_principal_outstanding            25637
# prosper_fees_paid                                       66
# prosper_rating                                           7
# prosper_score                                           12
# public_records_last10_years                             26
# public_records_last12_months                             8
# real_estate_balance                                  99150
# real_estate_payment                                   6080
# ref001                                                  33
# rep001                                                  30
# rep002                                                  48
# rep005                                                  30
# rep026                                                  18
# rep071                                                  28
# rep074                                                   8
# rep075                                                  16
# rep076                                                   9
# rep077                                                   6
# rep078                                                  16
# rep080                                                   6
# rep081                                                  16
# rep084                                                  16
# rep302                                               44568
# rep501                                                  11
# rep503                                                  11
# rep601                                                  10
# rep901                                                  63
# rep903                                                  62
# rep904                                                  56
# rep905                                                  56
# rep906                                                  61
# rep908                                                  69
# rev001                                                  89
# rev002                                                  89
# rev005                                                  89
# rev006                                                  53
# rev007                                                  55
# rev022                                                  29
# rev023                                                  39
# rev024                                                  57
# rev026                                                  53
# rev028                                                  50
# rev038                                                  45
# rev044                                                  23
# rev064                                                  12
# rev067                                                  12
# rev071                                                  85
# rev074                                                  16
# rev075                                                  28
# rev076                                                  18
# rev077                                                  11
# rev078                                                  28
# rev080                                                  12
# rev081                                                  28
# rev084                                                  28
# rev085                                                  11
# rev086                                                  15
# rev101                                                  56
# rev102                                                  57
# rev103                                                   7
# rev104                                                  13
# rev105                                                  10
# rev106                                                  17
# rev107                                                   9
# rev108                                                  12
# rev109                                                  14
# rev110                                                   5
# rev111                                                   6
# rev112                                                   5
# rev113                                                   7
# rev114                                                  13
# rev115                                                  15
# rev116                                                   8
# rev117                                                  13
# rev118                                                  11
# rev119                                                   8
# rev122                                                  10
# rev124                                                  13
# rev125                                                  16
# rev126                                                  61
# rev127                                                  23
# rev128                                                  23
# rev129                                                  23
# rev130                                                  23
# rev159                                                  46
# rev201                                               53499
# rev202                                               13638
# rev301                                               28883
# rev302                                               15560
# rev401                                               52288
# rev403                                                 127
# rev404                                                 137
# rev501                                                  11
# rev502                                                  11
# rev503                                                  11
# rev504                                                  11
# rev524                                                  99
# rev550                                                 462
# rev584                                                  29
# rev585                                                  53
# rev589                                                  29
# rev590                                                  53
# rev601                                                  10
# rev701                                                 601
# rev702                                                 196
# rev703                                                 324
# rev720                                                  87
# rev724                                                  87
# rev740                                                  87
# rev751                                                  15
# rev752                                                  27
# rev901                                                  86
# rev903                                                  86
# rev904                                                  80
# rev905                                                  80
# rev906                                                  80
# rev908                                                  96
# revolving_available_percent                            102
# revolving_balance                                    56945
# rti026                                                   6
# rtl001                                                  47
# rtl002                                                  53
# rtl005                                                  47
# rtl026                                                  29
# rtl071                                                  46
# rtl074                                                  12
# rtl075                                                  15
# rtl076                                                  13
# rtl077                                                   7
# rtl078                                                  15
# rtl080                                                   8
# rtl081                                                  15
# rtl084                                                  15
# rtl501                                                  11
# rtl502                                                  11
# rtl503                                                  11
# rtl901                                                  73
# rtl903                                                  74
# rtl904                                                  72
# rtl905                                                  71
# rtl906                                                  69
# rtl908                                                  91
# rtr001                                                  47
# rtr002                                                  52
# rtr005                                                  47
# rtr007                                                  34
# rtr022                                                  23
# rtr023                                                  27
# rtr026                                                  29
# rtr028                                                  28
# rtr031                                                  23
# rtr035                                                  15
# rtr044                                                  11
# rtr071                                                  46
# rtr074                                                  12
# rtr075                                                  15
# rtr076                                                  13
# rtr077                                                   7
# rtr078                                                  15
# rtr080                                                   8
# rtr081                                                  15
# rtr084                                                  15
# rtr159                                                  26
# rtr303                                                1993
# rtr401                                               19534
# rtr403                                                 162
# rtr501                                                  11
# rtr584                                                  29
# rtr585                                                  53
# rtr589                                                  29
# rtr590                                                  53
# rtr601                                                   9
# rtr751                                                  15
# rtr752                                                  27
# rtr901                                                  72
# rtr903                                                  73
# rtr904                                                  72
# rtr905                                                  71
# rtr906                                                  69
# rtr908                                                  91
# satisfactory_accounts                                  121
# scorex                                                  12
# scorex_change                                           16
# stated_monthly_income                                23855
# term                                                     3
# total_inquiries                                         76
# total_open_revolving_accounts                           56
# total_trade_items                                      119
# was_delinquent_derog                                    38
# dtype: int64

# %% [markdown]
# #### Run regressions

# %%
#columns to iterate over
cols = pd.read_sql('select * from merged_train limit 1', con=eng).columns
no_use_cols = ['loan_number','borrower_rate','term','amount_borrowed',
               'age_in_months','simple_return','analysis_class','listing_number',
               'member_key', 'first_recorded_credit_line', 'interest_paid', 
               'principal_paid','listing_term','prosper_rating']
cols = [c for c in cols if ('date' not in c and c not in no_use_cols)]

# %% [markdown]
# ### Test Run

# %%
col = 'is_homeowner'
stmt = ('select simple_return, age_in_months,' +
        'borrower_rate, payment, term, %s from merged_train where term<>12' %col)
df = pd.read_sql(stmt, con)
formula = ('simple_return ~ age_in_months + ' +
               'borrower_rate + payment + C(term) + C(%s)' %col)
reg = smf.ols(formula=formula, data=df, missing='drop')
model = reg.fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          simple_return   R-squared:                       0.323
# Model:                            OLS   Adj. R-squared:                  0.323
# Method:                 Least Squares   F-statistic:                 2.200e+04
# Date:                Mon, 31 Oct 2016   Prob (F-statistic):               0.00
# Time:                        04:29:04   Log-Likelihood:                -76127.
# No. Observations:              231070   AIC:                         1.523e+05
# Df Residuals:                  231064   BIC:                         1.523e+05
# Df Model:                           5
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -------------------------------------------------------------------------------------------
# Intercept                   0.3746      0.003    148.524      0.000         0.370     0.380
# C(term)[T.60]              -0.0973      0.002    -62.793      0.000        -0.100    -0.094
# C(is_homeowner)[T.True]     0.0252      0.001     17.443      0.000         0.022     0.028
# age_in_months               0.0089   3.16e-05    282.599      0.000         0.009     0.009
# borrower_rate               0.7395      0.012     60.645      0.000         0.716     0.763
# payment                 -6.206e-05   3.06e-06    -20.310      0.000     -6.81e-05 -5.61e-05
# ==============================================================================
# Omnibus:                      346.026   Durbin-Watson:                   1.385
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              374.878
# Skew:                          -0.064   Prob(JB):                     3.95e-82
# Kurtosis:                       3.150   Cond. No.                     7.57e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.57e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
pvals = model.pvalues
column = pvals.index.difference(['Intercept','C(term)[T.60]','age_in_months','borrower_rate','payment'])
pvals[column]
# Out:
# C(is_homeowner)[T.True]    4.285614e-68
# dtype: float64

# %%
outpt = pd.DataFrame()
outpt['pvalues'] = model.pvalues
outpt['rsquared'] = model.rsquared
outpt['coef'] = model.params
outpt['conf_low'] = model.conf_int()[0]
outpt['conf_high'] = model.conf_int()[1]

# %%
outpt.ix[column,:]
# Out:
#                               pvalues  rsquared      coef  conf_low  conf_high
# C(is_homeowner)[T.True]  4.285614e-68  0.322526  0.025155  0.022328   0.027981

# %% [markdown]
# ### Run Regressions Iteratively

# %%
cat_stmt = "select category from column_category where name='%s'" %col
cat = con.execute(cat_stmt).fetchone()[0]

# %%
cat
# Out:
# u'categorical'

# %%
column = pvals.index.difference(['Intercept','C(term)[T.60]','age_in_months','borrower_rate','payment','prosper_rating'])

# %%
#last minute get rid of columns with too many categories (they cause memory errors)
cols = [c for c in cols if c not in ['borrower_city']]

# %%
for i,col in enumerate(cols):
    #get category
    print col
    cat_stmt = "select category from column_category where name='%s'" %col
    cat = con.execute(cat_stmt).fetchone()[0]    
    if cat == 'categorical':
        formula = ('simple_return ~ age_in_months + ' +
                       'borrower_rate + payment + C(term) + C(%s)' %col)
    else:
        formula = ('simple_return ~ age_in_months + ' +
                       'borrower_rate + payment + C(term) + %s' %col)

    stmt = ('select simple_return, age_in_months,' +
            'borrower_rate, payment, term, %s from merged_train where term<>12' %col)
    df = pd.read_sql(stmt, con)
    if 'date' not in cat:
        #run regression
        reg = smf.ols(formula=formula, data=df, missing='drop')
        model = reg.fit()
        pvals = model.pvalues
        #get results
        outpt = pd.DataFrame()
        outpt['pvalues'] = pvals
        outpt['rsquared'] = model.rsquared
        outpt['coef'] = model.params
        outpt['conf_low'] = model.conf_int()[0]
        outpt['conf_high'] = model.conf_int()[1]
        columns = pvals.index.difference(['Intercept','C(term)[T.60]','age_in_months','borrower_rate',
                                         'payment','prosper_rating'])
        output = outpt.ix[columns,:]
        #write results
        output.to_sql('simple_regressions', con=con, if_exists='append',index=True, index_label='field')
        #print results
        print pvals[columns]
# Out:
# days_past_due
# days_past_due    0.0
# dtype: float64
# principal_balance
# principal_balance    0.0
# dtype: float64
# service_fees_paid
# service_fees_paid    0.0
# dtype: float64
# prosper_fees_paid
# prosper_fees_paid    5.041465e-33
# dtype: float64
# late_fees_paid
# late_fees_paid    7.659300e-70
# dtype: float64
# debt_sale_proceeds_received
# debt_sale_proceeds_received    2.542908e-54
# dtype: float64
# loan_status
# C(loan_status)[T.2]     0.000000e+00
# C(loan_status)[T.3]     0.000000e+00
# C(loan_status)[T.4]     0.000000e+00
# C(loan_status)[T.6]    2.991768e-287
# dtype: float64
# loan_status_description
# C(loan_status_description)[T.CHARGEOFF]     0.000000e+00
# C(loan_status_description)[T.COMPLETED]     1.704665e-04
# C(loan_status_description)[T.CURRENT]      2.991768e-287
# C(loan_status_description)[T.DEFAULTED]     0.000000e+00
# dtype: float64
# loan_default_reason
# C(loan_default_reason)[T.3.0]    1.309634e-24
# C(loan_default_reason)[T.4.0]    3.029138e-12
# C(loan_default_reason)[T.5.0]    0.000000e+00
# C(loan_default_reason)[T.6.0]    0.000000e+00
# C(loan_default_reason)[T.7.0]    4.788978e-36
# dtype: float64
# loan_default_reason_description
# C(loan_default_reason_description)[T.Deceased]         1.309634e-24
# C(loan_default_reason_description)[T.PaidInFull]       0.000000e+00
# C(loan_default_reason_description)[T.Repurchased]      3.029138e-12
# C(loan_default_reason_description)[T.SettledInFull]    0.000000e+00
# C(loan_default_reason_description)[T.Sold]             4.788978e-36
# dtype: float64
# next_payment_due_amount
# next_payment_due_amount    0.0
# dtype: float64
# payment
# payment[0]    0.238547
# payment[1]    0.238547
# dtype: float64
# listing_status
# Series([], dtype: float64)
# listing_status_reason
# Series([], dtype: float64)
# amount_funded
# amount_funded    1.741212e-08
# dtype: float64
# amount_remaining
# amount_remaining    0.054552
# dtype: float64
# percent_funded
# percent_funded    0.015197
# dtype: float64
# partial_funding_indicator
# C(partial_funding_indicator)[T.True]    0.0
# dtype: float64
# funding_threshold
# C(funding_threshold)[T.1.0]    0.0
# dtype: float64
# estimated_return
# estimated_return    0.0
# dtype: float64
# estimated_loss_rate
# estimated_loss_rate    0.0
# dtype: float64
# lender_yield
# lender_yield    0.0
# dtype: float64
# effective_yield
# effective_yield    0.0
# dtype: float64
# borrower_apr
# borrower_apr    0.0
# dtype: float64
# listing_monthly_payment
# listing_monthly_payment    1.293358e-12
# dtype: float64
# scorex
# C(scorex)[T.620-639]    2.967921e-02
# C(scorex)[T.640-649]    6.341916e-05
# C(scorex)[T.650-664]    4.908556e-02
# C(scorex)[T.665-689]    7.190379e-10
# C(scorex)[T.690-701]    9.887500e-13
# C(scorex)[T.702-723]    7.229059e-19
# C(scorex)[T.724-747]    6.726575e-22
# C(scorex)[T.748-777]    4.422524e-29
# C(scorex)[T.778+]       5.894967e-40
# C(scorex)[T.< 600]      9.120754e-03
# dtype: float64
# scorex_change
# C(scorex_change)[T.Decrease 101-120 Points]    4.556141e-01
# C(scorex_change)[T.Decrease 121+ Points]       8.347318e-02
# C(scorex_change)[T.Decrease 21-40 Points]      1.770344e-02
# C(scorex_change)[T.Decrease 41-60 Points]      1.832398e-09
# C(scorex_change)[T.Decrease 61-80 Points]      3.082618e-05
# C(scorex_change)[T.Decrease 81-100 Points]     1.033733e-04
# C(scorex_change)[T.Increase 1-20 Points]       5.309922e-03
# C(scorex_change)[T.Increase 101-120 Points]    2.802648e-05
# C(scorex_change)[T.Increase 121+ Points]       2.963238e-01
# C(scorex_change)[T.Increase 21-40 Points]      4.318366e-13
# C(scorex_change)[T.Increase 41-60 Points]      2.456809e-02
# C(scorex_change)[T.Increase 61-80 Points]      7.984997e-10
# C(scorex_change)[T.Increase 81-100 Points]     9.810923e-02
# C(scorex_change)[T.No Change]                  4.007813e-64
# dtype: float64
# fico_score
# C(fico_score)[T.620-639]    1.489055e-01
# C(fico_score)[T.640-659]    4.310554e-08
# C(fico_score)[T.660-679]    4.755942e-08
# C(fico_score)[T.680-699]    1.692181e-07
# C(fico_score)[T.700-719]    3.250924e-07
# C(fico_score)[T.720-739]    1.068445e-07
# C(fico_score)[T.740-759]    3.886304e-08
# C(fico_score)[T.760-779]    7.710923e-09
# C(fico_score)[T.780-799]    5.402239e-09
# C(fico_score)[T.800-819]    6.301791e-10
# C(fico_score)[T.820-850]    2.087247e-09
# C(fico_score)[T.< 600]      5.504841e-01
# dtype: float64
# prosper_score
# C(prosper_score)[T.10.0]    0.0
# C(prosper_score)[T.11.0]    0.0
# C(prosper_score)[T.2.0]     0.0
# C(prosper_score)[T.3.0]     0.0
# C(prosper_score)[T.4.0]     0.0
# C(prosper_score)[T.5.0]     0.0
# C(prosper_score)[T.6.0]     0.0
# C(prosper_score)[T.7.0]     0.0
# C(prosper_score)[T.8.0]     0.0
# C(prosper_score)[T.9.0]     0.0
# dtype: float64
# listing_category_id
# C(listing_category_id)[T.1.0]      0.000000e+00
# C(listing_category_id)[T.10.0]     4.182523e-54
# C(listing_category_id)[T.11.0]     0.000000e+00
# C(listing_category_id)[T.12.0]    3.089814e-100
# C(listing_category_id)[T.13.0]     0.000000e+00
# C(listing_category_id)[T.14.0]     0.000000e+00
# C(listing_category_id)[T.15.0]     0.000000e+00
# C(listing_category_id)[T.16.0]     0.000000e+00
# C(listing_category_id)[T.17.0]    1.433213e-165
# C(listing_category_id)[T.18.0]     0.000000e+00
# C(listing_category_id)[T.19.0]     0.000000e+00
# C(listing_category_id)[T.2.0]      0.000000e+00
# C(listing_category_id)[T.20.0]     0.000000e+00
# C(listing_category_id)[T.21.0]     0.000000e+00
# C(listing_category_id)[T.3.0]      0.000000e+00
# C(listing_category_id)[T.4.0]      1.098284e-13
# C(listing_category_id)[T.5.0]      2.088781e-61
# C(listing_category_id)[T.6.0]      0.000000e+00
# C(listing_category_id)[T.7.0]      0.000000e+00
# C(listing_category_id)[T.8.0]      0.000000e+00
# C(listing_category_id)[T.9.0]     1.350307e-211
# dtype: float64
# income_range
# C(income_range)[T.1.0]    9.935001e-01
# C(income_range)[T.2.0]    2.316956e-31
# C(income_range)[T.3.0]    1.333919e-40
# C(income_range)[T.4.0]    2.892143e-50
# C(income_range)[T.5.0]    5.010104e-55
# C(income_range)[T.6.0]    5.133577e-59
# C(income_range)[T.7.0]    2.720795e-25
# dtype: float64
# income_range_description
# C(income_range_description)[T.$1-24,999]         9.908437e-101
# C(income_range_description)[T.$100,000+]         2.591884e-196
# C(income_range_description)[T.$25,000-49,999]    3.350896e-134
# C(income_range_description)[T.$50,000-74,999]    3.889163e-167
# C(income_range_description)[T.$75,000-99,999]    7.972674e-183
# C(income_range_description)[T.Not displayed]      9.935001e-01
# C(income_range_description)[T.Not employed]       1.620923e-53
# dtype: float64
# stated_monthly_income
# stated_monthly_income    0.00798
# dtype: float64
# income_verifiable
# C(income_verifiable)[T.True]    2.168638e-34
# dtype: float64
# dti_wprosper_loan
# dti_wprosper_loan    2.274994e-38
# dtype: float64
# employment_status_description
# C(employment_status_description)[T.Full-time]        0.000000e+00
# C(employment_status_description)[T.Not available]    6.846584e-47
# C(employment_status_description)[T.Not employed]     1.482268e-94
# C(employment_status_description)[T.Other]            3.226573e-75
# C(employment_status_description)[T.Part-time]        0.000000e+00
# C(employment_status_description)[T.Retired]          0.000000e+00
# C(employment_status_description)[T.Self-employed]    0.000000e+00
# dtype: float64
# occupation
# C(occupation)[T.Administrative Assistant]              3.745019e-06
# C(occupation)[T.Analyst]                               3.163683e-01
# C(occupation)[T.Architect]                             2.331405e-01
# C(occupation)[T.Attorney]                              5.297088e-02
# C(occupation)[T.Biologist]                             6.117968e-01
# C(occupation)[T.Bus Driver]                            1.029896e-07
# C(occupation)[T.Car Dealer]                            2.446612e-03
# C(occupation)[T.Chemist]                               2.315281e-01
# C(occupation)[T.Civil Service]                         1.404224e-01
# C(occupation)[T.Clergy]                                5.952922e-01
# C(occupation)[T.Clerical]                              1.411827e-17
# C(occupation)[T.Computer Programmer]                   4.091518e-01
# C(occupation)[T.Construction]                          4.182908e-23
# C(occupation)[T.Dentist]                               5.937725e-03
# C(occupation)[T.Doctor]                                3.225652e-01
# C(occupation)[T.Engineer - Chemical]                   9.017674e-01
# C(occupation)[T.Engineer - Electrical]                 1.744969e-01
# C(occupation)[T.Engineer - Mechanical]                 5.994051e-02
# C(occupation)[T.Executive]                             4.813032e-01
# C(occupation)[T.Fireman]                               4.308290e-01
# C(occupation)[T.Flight Attendant]                      1.128744e-01
# C(occupation)[T.Food Service Management]               1.179100e-08
# C(occupation)[T.Food Service]                          2.662703e-34
# C(occupation)[T.Homemaker]                             5.999245e-12
# C(occupation)[T.Investor]                              1.123650e-02
# C(occupation)[T.Judge]                                 2.758781e-01
# C(occupation)[T.Laborer]                               2.689693e-18
# C(occupation)[T.Landscaping]                           2.297123e-07
# C(occupation)[T.Medical Technician]                    7.472609e-06
# C(occupation)[T.Military Enlisted]                     2.196689e-01
#                                                            ...
# C(occupation)[T.Pilot - Private/Commercial]            1.852348e-01
# C(occupation)[T.Police Officer/Correction Officer]     9.779358e-01
# C(occupation)[T.Postal Service]                        1.793089e-02
# C(occupation)[T.Principal]                             2.918524e-01
# C(occupation)[T.Professional]                          8.659228e-01
# C(occupation)[T.Professor]                             4.495175e-01
# C(occupation)[T.Psychologist]                          4.054887e-01
# C(occupation)[T.Realtor]                               4.083062e-40
# C(occupation)[T.Religious]                             1.206563e-02
# C(occupation)[T.Retail Management]                     1.468903e-07
# C(occupation)[T.Sales - Commission]                    5.903441e-20
# C(occupation)[T.Sales - Retail]                        1.724370e-22
# C(occupation)[T.Scientist]                             6.287055e-01
# C(occupation)[T.Skilled Labor]                         5.268186e-16
# C(occupation)[T.Social Worker]                         5.544934e-04
# C(occupation)[T.Student - College Freshman]            5.001751e-06
# C(occupation)[T.Student - College Graduate Student]    2.799194e-07
# C(occupation)[T.Student - College Junior]              6.226692e-08
# C(occupation)[T.Student - College Senior]              5.005551e-06
# C(occupation)[T.Student - College Sophomore]           1.115289e-08
# C(occupation)[T.Student - Community College]           4.293441e-04
# C(occupation)[T.Student - Technical School]            1.188909e-05
# C(occupation)[T.Teacher's Aide]                        8.586585e-06
# C(occupation)[T.Teacher]                               1.224514e-06
# C(occupation)[T.Tradesman - Carpenter]                 1.080809e-04
# C(occupation)[T.Tradesman - Electrician]               3.058602e-02
# C(occupation)[T.Tradesman - Mechanic]                  1.050909e-04
# C(occupation)[T.Tradesman - Plumber]                   3.701012e-02
# C(occupation)[T.Truck Driver]                          6.526966e-16
# C(occupation)[T.Waiter/Waitress]                       1.686125e-13
# dtype: float64
# months_employed
# months_employed    4.523937e-07
# dtype: float64
# borrower_state
# C(borrower_state)[T.AL]    7.114587e-02
# C(borrower_state)[T.AR]    8.471746e-01
# C(borrower_state)[T.AZ]    2.087808e-01
# C(borrower_state)[T.CA]    6.105286e-01
# C(borrower_state)[T.CO]    2.748313e-01
# C(borrower_state)[T.CT]    7.715427e-04
# C(borrower_state)[T.DC]    9.468998e-03
# C(borrower_state)[T.DE]    6.729027e-01
# C(borrower_state)[T.FL]    2.969998e-02
# C(borrower_state)[T.GA]    2.620457e-02
# C(borrower_state)[T.HI]    9.549812e-01
# C(borrower_state)[T.IA]    7.020910e-33
# C(borrower_state)[T.ID]    9.376501e-01
# C(borrower_state)[T.IL]    1.454060e-01
# C(borrower_state)[T.IN]    1.575270e-01
# C(borrower_state)[T.KS]    3.146360e-01
# C(borrower_state)[T.KY]    7.846991e-01
# C(borrower_state)[T.LA]    1.390430e-01
# C(borrower_state)[T.MA]    1.499385e-02
# C(borrower_state)[T.MD]    9.351218e-02
# C(borrower_state)[T.ME]    5.394999e-19
# C(borrower_state)[T.MI]    2.579790e-01
# C(borrower_state)[T.MN]    7.641025e-02
# C(borrower_state)[T.MO]    1.095406e-01
# C(borrower_state)[T.MS]    2.634969e-01
# C(borrower_state)[T.MT]    3.942971e-01
# C(borrower_state)[T.NC]    2.814298e-01
# C(borrower_state)[T.ND]    9.017381e-06
# C(borrower_state)[T.NE]    3.323452e-01
# C(borrower_state)[T.NH]    4.268389e-01
# C(borrower_state)[T.NJ]    6.522773e-01
# C(borrower_state)[T.NM]    8.493902e-01
# C(borrower_state)[T.NV]    8.267180e-01
# C(borrower_state)[T.NY]    6.032058e-01
# C(borrower_state)[T.OH]    2.853225e-01
# C(borrower_state)[T.OK]    3.958449e-02
# C(borrower_state)[T.OR]    4.731276e-01
# C(borrower_state)[T.PA]    1.608969e-18
# C(borrower_state)[T.RI]    5.768020e-01
# C(borrower_state)[T.SC]    8.298751e-01
# C(borrower_state)[T.SD]    3.360923e-01
# C(borrower_state)[T.TN]    5.135830e-01
# C(borrower_state)[T.TX]    9.270478e-01
# C(borrower_state)[T.UT]    1.277892e-01
# C(borrower_state)[T.VA]    8.500998e-01
# C(borrower_state)[T.VT]    2.173867e-02
# C(borrower_state)[T.WA]    1.919429e-01
# C(borrower_state)[T.WI]    7.122279e-01
# C(borrower_state)[T.WV]    5.856194e-01
# C(borrower_state)[T.WY]    8.693442e-01
# dtype: float64
# borrower_city
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-18-0fa0853a0809> in <module>()
#      16     if 'date' not in cat:
#      17         #run regression
# ---> 18         reg = smf.ols(formula=formula, data=df, missing='drop')
#      19         model = reg.fit()
#      20         pvals = model.pvalues
#
# /usr/local/lib64/python2.7/site-packages/statsmodels/base/model.pyc in from_formula(cls, formula, data, subset, *args, **kwargs)
#     145         (endog, exog), missing_idx = handle_formula_data(data, None, formula,
#     146                                                          depth=eval_env,
# --> 147                                                          missing=missing)
#     148         kwargs.update({'missing_idx': missing_idx,
#     149                        'missing': missing})
#
# /usr/local/lib64/python2.7/site-packages/statsmodels/formula/formulatools.pyc in handle_formula_data(Y, X, formula, depth, missing)
#      63         if data_util._is_using_pandas(Y, None):
#      64             result = dmatrices(formula, Y, depth, return_type='dataframe',
# ---> 65                                NA_action=na_action)
#      66         else:
#      67             result = dmatrices(formula, Y, depth, return_type='dataframe',
#
# /usr/local/lib/python2.7/site-packages/patsy/highlevel.pyc in dmatrices(formula_like, data, eval_env, NA_action, return_type)
#     308     eval_env = EvalEnvironment.capture(eval_env, reference=1)
#     309     (lhs, rhs) = _do_highlevel_design(formula_like, data, eval_env,
# --> 310                                       NA_action, return_type)
#     311     if lhs.shape[1] == 0:
#     312         raise PatsyError("model is missing required outcome variables")
#
# /usr/local/lib/python2.7/site-packages/patsy/highlevel.pyc in _do_highlevel_design(formula_like, data, eval_env, NA_action, return_type)
#     167         return build_design_matrices(design_infos, data,
#     168                                      NA_action=NA_action,
# --> 169                                      return_type=return_type)
#     170     else:
#     171         # No builders, but maybe we can still get matrices
#
# /usr/local/lib/python2.7/site-packages/patsy/build.pyc in build_design_matrices(design_infos, data, NA_action, return_type, dtype)
#     931         results.append(_build_design_matrix(design_info,
#     932                                             factor_info_to_values,
# --> 933                                             dtype))
#     934     matrices = []
#     935     for need_reshape, matrix in results:
#
# /usr/local/lib/python2.7/site-packages/patsy/build.pyc in _build_design_matrix(design_info, factor_info_to_values, dtype)
#     760         need_reshape = True
#     761     shape = (num_rows, len(design_info.column_names))
# --> 762     m = DesignMatrix(np.empty(shape, dtype=dtype), design_info)
#     763     start_column = 0
#     764     for term, subterms in six.iteritems(design_info.term_codings):
#
# MemoryError:

# %% [markdown]
# I for got to get rid of the 'borrower city' field, which uses too much memory.
#
# I continue after this index.

# %%
cols.index('borrower_city')
# Out:
# 39

# %%
for i,col in enumerate(cols[cols.index('borrower_city')+1:]):
    #get category
    print col
    cat_stmt = "select category from column_category where name='%s'" %col
    cat = con.execute(cat_stmt).fetchone()[0]    
    if cat == 'categorical':
        formula = ('simple_return ~ age_in_months + ' +
                       'borrower_rate + payment + C(term) + C(%s)' %col)
    else:
        formula = ('simple_return ~ age_in_months + ' +
                       'borrower_rate + payment + C(term) + %s' %col)

    stmt = ('select simple_return, age_in_months,' +
            'borrower_rate, payment, term, %s from merged_train where term<>12' %col)
    df = pd.read_sql(stmt, con)
    if 'date' not in cat:
        #run regression
        reg = smf.ols(formula=formula, data=df, missing='drop')
        model = reg.fit()
        pvals = model.pvalues
        #get results
        outpt = pd.DataFrame()
        outpt['pvalues'] = pvals
        outpt['rsquared'] = model.rsquared
        outpt['coef'] = model.params
        outpt['conf_low'] = model.conf_int()[0]
        outpt['conf_high'] = model.conf_int()[1]
        columns = pvals.index.difference(['Intercept','C(term)[T.60]','age_in_months','borrower_rate',
                                         'payment','prosper_rating'])
        output = outpt.ix[columns,:]
        #write results
        output.to_sql('simple_regressions', con=con, if_exists='append',index=True, index_label='field')
        #print results
        print pvals[columns]
# Out:
# prior_prosper_loans_active
# prior_prosper_loans_active    0.000941
# dtype: float64
# prior_prosper_loans
# prior_prosper_loans    1.951761e-91
# dtype: float64
# prior_prosper_loans_principal_borrowed
# prior_prosper_loans_principal_borrowed    0.000009
# dtype: float64
# prior_prosper_loans_principal_outstanding
# prior_prosper_loans_principal_outstanding    4.166028e-76
# dtype: float64
# prior_prosper_loans_balance_outstanding
# prior_prosper_loans_balance_outstanding    8.940177e-76
# dtype: float64
# prior_prosper_loans_cycles_billed
# prior_prosper_loans_cycles_billed    1.081401e-65
# dtype: float64
# prior_prosper_loans_ontime_payments
# prior_prosper_loans_ontime_payments    1.970251e-64
# dtype: float64
# prior_prosper_loans_late_cycles
# prior_prosper_loans_late_cycles    0.000032
# dtype: float64
# prior_prosper_loans_late_payments_one_month_plus
# prior_prosper_loans_late_payments_one_month_plus    0.128805
# dtype: float64
# max_prior_prosper_loan
# max_prior_prosper_loan    6.915650e-65
# dtype: float64
# min_prior_prosper_loan
# min_prior_prosper_loan    1.723004e-122
# dtype: float64
# prior_prosper_loan_earliest_pay_off
# prior_prosper_loan_earliest_pay_off    0.000048
# dtype: float64
# lender_indicator
# C(lender_indicator)[T.1.0]    9.624301e-61
# dtype: float64
# all001
# all001    0.0
# dtype: float64
# all002
# all002    1.876230e-163
# dtype: float64
# all003
# all003    0.002106
# dtype: float64
# all005
# all005    1.101891e-171
# dtype: float64
# all006
# all006    0.055004
# dtype: float64
# all007
# all007    0.003746
# dtype: float64
# all010
# all010    2.052728e-08
# dtype: float64
# all021
# all021    5.624630e-39
# dtype: float64
# all022
# all022    3.450657e-92
# dtype: float64
# all023
# all023    2.240137e-94
# dtype: float64
# all024
# all024    1.306510e-21
# dtype: float64
# all026
# all026    7.358918e-44
# dtype: float64
# all051
# all051    2.158384e-35
# dtype: float64
# all052
# all052    2.680501e-23
# dtype: float64
# all062
# all062    6.303371e-54
# dtype: float64
# all064
# all064    6.167613e-28
# dtype: float64
# all067
# all067    0.851381
# dtype: float64
# all071
# all071    4.071150e-149
# dtype: float64
# all081
# all081    3.321002e-42
# dtype: float64
# all082
# all082    0.678679
# dtype: float64
# all090
# all090    7.139317e-48
# dtype: float64
# all101
# all101    5.070099e-09
# dtype: float64
# all102
# all102    6.509972e-21
# dtype: float64
# all106
# all106    0.014906
# dtype: float64
# all108
# all108    0.272781
# dtype: float64
# all118
# all118    0.006327
# dtype: float64
# all124
# all124    0.032236
# dtype: float64
# all126
# all126    8.398939e-39
# dtype: float64
# all127
# all127    8.600998e-07
# dtype: float64
# all130
# all130    3.918173e-16
# dtype: float64
# all134
# all134    0.45369
# dtype: float64
# all136
# all136    0.374499
# dtype: float64
# all141
# all141    0.030084
# dtype: float64
# all142
# all142    4.026967e-11
# dtype: float64
# all144
# all144    0.070589
# dtype: float64
# all145
# all145    7.211106e-08
# dtype: float64
# all146
# all146    4.957432e-31
# dtype: float64
# all151
# all151    4.960042e-42
# dtype: float64
# all155
# all155    1.282816e-44
# dtype: float64
# all156
# all156    0.011036
# dtype: float64
# all201
# all201    2.770228e-15
# dtype: float64
# all202
# all202    1.877620e-62
# dtype: float64
# all207
# all207    0.033112
# dtype: float64
# all208
# all208    1.456777e-09
# dtype: float64
# all301
# all301    9.720001e-50
# dtype: float64
# all403
# all403    3.965703e-19
# dtype: float64
# all501
# C(all501)[T.120.0]    8.721602e-01
# C(all501)[T.150.0]    7.743027e-01
# C(all501)[T.180.0]    4.100822e-01
# C(all501)[T.30.0]     5.367842e-02
# C(all501)[T.34.0]     5.193824e-01
# C(all501)[T.400.0]    1.278257e-29
# C(all501)[T.60.0]     1.449936e-02
# C(all501)[T.90.0]     2.640281e-01
# dtype: float64
# all502
# C(all502)[T.120.0]    9.098470e-01
# C(all502)[T.150.0]    1.992466e-01
# C(all502)[T.180.0]    2.304904e-01
# C(all502)[T.30.0]     8.801725e-01
# C(all502)[T.34.0]     9.422860e-01
# C(all502)[T.400.0]    3.161606e-08
# C(all502)[T.60.0]     3.670200e-01
# C(all502)[T.90.0]     2.054258e-02
# dtype: float64
# all503
# C(all503)[T.120.0]    8.706095e-01
# C(all503)[T.150.0]    2.464532e-01
# C(all503)[T.180.0]    1.441165e-01
# C(all503)[T.30.0]     2.340158e-01
# C(all503)[T.34.0]     6.791657e-01
# C(all503)[T.400.0]    4.656197e-13
# C(all503)[T.60.0]     4.271567e-01
# C(all503)[T.90.0]     1.021123e-01
# dtype: float64
# all504
# C(all504)[T.1.0]      0.000003
# C(all504)[T.120.0]    0.075545
# C(all504)[T.150.0]    0.031099
# C(all504)[T.180.0]    0.226846
# C(all504)[T.30.0]     0.003980
# C(all504)[T.34.0]     0.729721
# C(all504)[T.400.0]    0.000004
# C(all504)[T.60.0]     0.282513
# C(all504)[T.90.0]     0.153082
# dtype: float64
# all505
# C(all505)[T.1.0]      2.361469e-30
# C(all505)[T.120.0]    4.695809e-01
# C(all505)[T.150.0]    1.347084e-01
# C(all505)[T.180.0]    3.699483e-05
# C(all505)[T.30.0]     1.475857e-04
# C(all505)[T.34.0]     5.427779e-02
# C(all505)[T.400.0]    7.155493e-05
# C(all505)[T.60.0]     2.342773e-02
# C(all505)[T.90.0]     5.011348e-01
# dtype: float64
# all524
# all524    0.232791
# dtype: float64
# all601
# C(all601)[T.120.0]    0.651738
# C(all601)[T.150.0]    0.257062
# C(all601)[T.180.0]    0.842059
# C(all601)[T.30.0]     0.153021
# C(all601)[T.34.0]     0.766481
# C(all601)[T.60.0]     0.546770
# C(all601)[T.90.0]     0.186140
# dtype: float64
# all701
# all701    1.182374e-68
# dtype: float64
# all702
# all702    1.747880e-38
# dtype: float64
# all703
# all703    8.179664e-09
# dtype: float64
# all720
# all720    1.853064e-18
# dtype: float64
# all740
# all740    8.953081e-24
# dtype: float64
# all780
# all780    0.000002
# dtype: float64
# all790
# all790    0.686394
# dtype: float64
# all801
# all801    2.577763e-166
# dtype: float64
# all803
# all803    1.112316e-150
# dtype: float64
# all804
# all804    1.930826e-177
# dtype: float64
# all805
# all805    9.793879e-25
# dtype: float64
# all806
# all806    6.407938e-169
# dtype: float64
# all807
# all807    7.185091e-175
# dtype: float64
# all901
# all901    4.778485e-16
# dtype: float64
# all903
# all903    2.728442e-07
# dtype: float64
# all904
# all904    8.568634e-17
# dtype: float64
# all905
# all905    8.088931e-18
# dtype: float64
# all906
# all906    1.361450e-22
# dtype: float64
# bac001
# bac001    8.171688e-56
# dtype: float64
# bac002
# bac002    1.092962e-60
# dtype: float64
# bac005
# bac005    8.171688e-56
# dtype: float64
# bac007
# bac007    0.000013
# dtype: float64
# bac022
# bac022    6.886323e-16
# dtype: float64
# bac026
# bac026    6.609303e-10
# dtype: float64
# bac028
# bac028    1.380987e-09
# dtype: float64
# bac031
# bac031    1.244023e-61
# dtype: float64
# bac035
# bac035    1.117362e-62
# dtype: float64
# bac042
# bac042    7.486763e-84
# dtype: float64
# bac044
# bac044    7.725570e-26
# dtype: float64
# bac045
# bac045    0.149049
# dtype: float64
# bac071
# bac071    4.085776e-38
# dtype: float64
# bac081
# bac081    1.210083e-43
# dtype: float64
# bac084
# bac084    2.748908e-45
# dtype: float64
# bac159
# bac159    5.827244e-17
# dtype: float64
# bac302
# bac302    0.000009
# dtype: float64
# bac303
# bac303    0.001084
# dtype: float64
# bac401
# bac401    0.96123
# dtype: float64
# bac403
# bac403    1.852298e-09
# dtype: float64
# bac501
# C(bac501)[T.1.0]      0.998892
# C(bac501)[T.120.0]    0.886122
# C(bac501)[T.150.0]    0.971743
# C(bac501)[T.180.0]    0.912750
# C(bac501)[T.30.0]     0.937681
# C(bac501)[T.34.0]     0.925600
# C(bac501)[T.400.0]    0.403393
# C(bac501)[T.60.0]     0.794339
# C(bac501)[T.90.0]     0.901461
# dtype: float64
# bac502
# C(bac502)[T.1.0]      0.055489
# C(bac502)[T.120.0]    0.718497
# C(bac502)[T.150.0]    0.043593
# C(bac502)[T.180.0]    0.052110
# C(bac502)[T.30.0]     0.031582
# C(bac502)[T.34.0]     0.862897
# C(bac502)[T.400.0]    0.204111
# C(bac502)[T.60.0]     0.009459
# C(bac502)[T.90.0]     0.018495
# dtype: float64
# bac503
# C(bac503)[T.1.0]      0.113184
# C(bac503)[T.120.0]    0.214079
# C(bac503)[T.150.0]    0.227925
# C(bac503)[T.180.0]    0.029602
# C(bac503)[T.30.0]     0.043792
# C(bac503)[T.34.0]     0.507376
# C(bac503)[T.400.0]    0.281972
# C(bac503)[T.60.0]     0.158465
# C(bac503)[T.90.0]     0.051264
# dtype: float64
# bac550
# bac550    4.773632e-117
# dtype: float64
# bac584
# bac584    0.001818
# dtype: float64
# bac589
# bac589    0.046575
# dtype: float64
# bac601
# C(bac601)[T.1.0]      0.006029
# C(bac601)[T.120.0]    0.003296
# C(bac601)[T.150.0]    0.275984
# C(bac601)[T.180.0]    0.225597
# C(bac601)[T.30.0]     0.003990
# C(bac601)[T.34.0]     0.924883
# C(bac601)[T.60.0]     0.514541
# C(bac601)[T.90.0]     0.520355
# dtype: float64
# bac751
# bac751    2.300336e-13
# dtype: float64
# bac752
# bac752    2.153048e-18
# dtype: float64
# bac804
# bac804    2.106131e-37
# dtype: float64
# bac901
# bac901    5.352852e-16
# dtype: float64
# bac908
# bac908    1.809453e-26
# dtype: float64
# bnk026
# bnk026    1.410529e-19
# dtype: float64
# brr026
# brr026    0.000523
# dtype: float64
# fil022
# fil022    2.229659e-38
# dtype: float64
# fin601
# C(fin601)[T.1.0]      0.001517
# C(fin601)[T.120.0]    0.608845
# C(fin601)[T.150.0]    0.684674
# C(fin601)[T.180.0]    0.726408
# C(fin601)[T.30.0]     0.947524
# C(fin601)[T.34.0]     0.429892
# C(fin601)[T.60.0]     0.382409
# C(fin601)[T.90.0]     0.550008
# dtype: float64
# heq001
# heq001    5.982061e-23
# dtype: float64
# iln002
# iln002    2.422299e-93
# dtype: float64
# iln007
# iln007    3.748319e-13
# dtype: float64
# iln022
# iln022    3.974405e-93
# dtype: float64
# iln023
# iln023    6.035134e-119
# dtype: float64
# iln071
# iln071    4.366031e-140
# dtype: float64
# iln075
# iln075    5.125607e-11
# dtype: float64
# iln081
# iln081    4.934370e-11
# dtype: float64
# iln101
# iln101    3.311867e-27
# dtype: float64
# iln102
# iln102    6.146735e-48
# dtype: float64
# iln112
# iln112    0.130461
# dtype: float64
# iln126
# iln126    2.139939e-70
# dtype: float64
# iln127
# iln127    0.025794
# dtype: float64
# iln201
# iln201    2.436441e-48
# dtype: float64
# iln301
# iln301    3.275538e-24
# dtype: float64
# iln403
# iln403    4.577140e-30
# dtype: float64
# iln502
# C(iln502)[T.1.0]      5.319098e-17
# C(iln502)[T.120.0]    2.850625e-01
# C(iln502)[T.150.0]    9.734546e-01
# C(iln502)[T.180.0]    9.579788e-01
# C(iln502)[T.30.0]     1.295866e-03
# C(iln502)[T.34.0]     1.595662e-01
# C(iln502)[T.400.0]    1.693802e-07
# C(iln502)[T.60.0]     3.520575e-01
# C(iln502)[T.90.0]     2.642086e-01
# dtype: float64
# iln503
# C(iln503)[T.1.0]      2.661910e-18
# C(iln503)[T.120.0]    8.234071e-01
# C(iln503)[T.150.0]    6.917046e-02
# C(iln503)[T.180.0]    5.856344e-02
# C(iln503)[T.30.0]     1.156702e-07
# C(iln503)[T.34.0]     1.410566e-01
# C(iln503)[T.400.0]    8.162396e-15
# C(iln503)[T.60.0]     1.111880e-03
# C(iln503)[T.90.0]     2.031038e-01
# dtype: float64
# iln601
# C(iln601)[T.1.0]      2.460787e-13
# C(iln601)[T.120.0]    1.134891e-01
# C(iln601)[T.150.0]    9.146314e-01
# C(iln601)[T.180.0]    9.533830e-01
# C(iln601)[T.30.0]     9.334511e-01
# C(iln601)[T.34.0]     3.910052e-01
# C(iln601)[T.60.0]     1.995981e-01
# C(iln601)[T.90.0]     9.817534e-01
# dtype: float64
# iln701
# iln701    1.014839e-13
# dtype: float64
# iln702
# iln702    5.087633e-22
# dtype: float64
# iln804
# iln804    5.528465e-99
# dtype: float64
# iln901
# iln901    1.112664e-17
# dtype: float64
# iln903
# iln903    0.980741
# dtype: float64
# iln908
# iln908    7.243612e-17
# dtype: float64
# iln914
# iln914    7.832445e-41
# dtype: float64
# ref001
# ref001    6.842967e-161
# dtype: float64
# rep001
# rep001    5.831982e-130
# dtype: float64
# rep002
# rep002    1.860506e-130
# dtype: float64
# rep026
# rep026    4.436676e-49
# dtype: float64
# rep075
# rep075    7.121706e-32
# dtype: float64
# rep302
# rep302    1.197130e-39
# dtype: float64
# rep503
# C(rep503)[T.1.0]      4.044870e-71
# C(rep503)[T.120.0]    7.583209e-01
# C(rep503)[T.150.0]    2.247100e-01
# C(rep503)[T.180.0]    1.514944e-01
# C(rep503)[T.30.0]     1.459927e-02
# C(rep503)[T.34.0]     6.346644e-01
# C(rep503)[T.400.0]    1.517931e-23
# C(rep503)[T.60.0]     7.701508e-01
# C(rep503)[T.90.0]     5.589442e-01
# dtype: float64
# rep601
# C(rep601)[T.1.0]      4.487573e-54
# C(rep601)[T.120.0]    3.967021e-01
# C(rep601)[T.150.0]    3.945797e-01
# C(rep601)[T.180.0]    9.833151e-01
# C(rep601)[T.30.0]     2.799659e-01
# C(rep601)[T.34.0]     3.131716e-01
# C(rep601)[T.60.0]     4.898279e-01
# C(rep601)[T.90.0]     7.361525e-02
# dtype: float64
# rep904
# rep904    3.418907e-16
# dtype: float64
# rep908
# rep908    5.978396e-48
# dtype: float64
# rev001
# rev001    4.192241e-61
# dtype: float64
# rev002
# rev002    3.134518e-62
# dtype: float64
# rev006
# rev006    0.000667
# dtype: float64
# rev007
# rev007    0.03083
# dtype: float64
# rev022
# rev022    8.264806e-25
# dtype: float64
# rev024
# rev024    0.430556
# dtype: float64
# rev026
# rev026    0.000603
# dtype: float64
# rev028
# rev028    0.000001
# dtype: float64
# rev038
# rev038    0.076198
# dtype: float64
# rev071
# rev071    2.777229e-48
# dtype: float64
# rev081
# rev081    1.677658e-40
# dtype: float64
# rev086
# rev086    4.277547e-08
# dtype: float64
# rev101
# rev101    0.133938
# dtype: float64
# rev102
# rev102    0.485831
# dtype: float64
# rev106
# rev106    0.225067
# dtype: float64
# rev115
# rev115    0.000018
# dtype: float64
# rev125
# rev125    0.00215
# dtype: float64
# rev126
# rev126    0.007899
# dtype: float64
# rev130
# rev130    2.428452e-15
# dtype: float64
# rev159
# rev159    3.946816e-14
# dtype: float64
# rev201
# rev201    0.348353
# dtype: float64
# rev202
# rev202    0.691647
# dtype: float64
# rev301
# rev301    0.167926
# dtype: float64
# rev302
# rev302    0.000246
# dtype: float64
# rev401
# rev401    6.762336e-07
# dtype: float64
# rev403
# rev403    1.002796e-48
# dtype: float64
# rev502
# C(rev502)[T.1.0]      0.360297
# C(rev502)[T.120.0]    0.308163
# C(rev502)[T.150.0]    0.029469
# C(rev502)[T.180.0]    0.277304
# C(rev502)[T.30.0]     0.336566
# C(rev502)[T.34.0]     0.840703
# C(rev502)[T.400.0]    0.919722
# C(rev502)[T.60.0]     0.146686
# C(rev502)[T.90.0]     0.099167
# dtype: float64
# rev503
# C(rev503)[T.1.0]      0.487208
# C(rev503)[T.120.0]    0.521684
# C(rev503)[T.150.0]    0.465850
# C(rev503)[T.180.0]    0.208137
# C(rev503)[T.30.0]     0.438450
# C(rev503)[T.34.0]     0.574877
# C(rev503)[T.400.0]    0.976861
# C(rev503)[T.60.0]     0.485598
# C(rev503)[T.90.0]     0.348828
# dtype: float64
# rev524
# rev524    0.3543
# dtype: float64
# rev550
# rev550    6.960613e-135
# dtype: float64
# rev584
# rev584    8.708327e-07
# dtype: float64
# rev585
# rev585    4.414980e-13
# dtype: float64
# rev589
# rev589    0.007207
# dtype: float64
# rev590
# rev590    0.008348
# dtype: float64
# rev601
# C(rev601)[T.1.0]      0.261424
# C(rev601)[T.120.0]    0.324901
# C(rev601)[T.150.0]    0.210191
# C(rev601)[T.180.0]    0.971823
# C(rev601)[T.30.0]     0.166432
# C(rev601)[T.34.0]     0.575120
# C(rev601)[T.60.0]     0.873545
# C(rev601)[T.90.0]     0.644029
# dtype: float64
# rev701
# rev701    0.512796
# dtype: float64
# rev702
# rev702    0.480035
# dtype: float64
# rev703
# rev703    0.100467
# dtype: float64
# rev720
# rev720    8.474925e-22
# dtype: float64
# rev740
# rev740    1.282484e-37
# dtype: float64
# rev751
# rev751    1.304793e-19
# dtype: float64
# rev752
# rev752    4.994991e-26
# dtype: float64
# rev901
# rev901    1.427298e-12
# dtype: float64
# rev904
# rev904    2.715299e-25
# dtype: float64
# rev908
# rev908    5.506764e-37
# dtype: float64
# rtl001
# rtl001    1.074922e-23
# dtype: float64
# rtl002
# rtl002    2.375128e-22
# dtype: float64
# rtr001
# rtr001    1.172505e-24
# dtype: float64
# rtr002
# rtr002    3.358369e-23
# dtype: float64
# rtr005
# rtr005    1.172505e-24
# dtype: float64
# rtr026
# rtr026    0.955218
# dtype: float64
# rtr159
# rtr159    0.02248
# dtype: float64
# rtr303
# rtr303    0.02358
# dtype: float64
# rtr401
# rtr401    0.588119
# dtype: float64
# rtr403
# rtr403    3.922436e-17
# dtype: float64
# rtr501
# C(rtr501)[T.1.0]      1.472955e-04
# C(rtr501)[T.120.0]    4.055998e-01
# C(rtr501)[T.150.0]    7.198571e-01
# C(rtr501)[T.180.0]    6.583343e-01
# C(rtr501)[T.30.0]     1.597547e-02
# C(rtr501)[T.34.0]     7.299954e-01
# C(rtr501)[T.400.0]    6.837872e-21
# C(rtr501)[T.60.0]     2.448059e-02
# C(rtr501)[T.90.0]     6.377070e-01
# dtype: float64
# rtr903
# rtr903    0.143162
# dtype: float64
# ale001
# ale001    6.323898e-156
# dtype: float64
# ale002
# ale002    7.703473e-153
# dtype: float64
# ale005
# ale005    6.323898e-156
# dtype: float64
# ale007
# ale007    2.556668e-42
# dtype: float64
# ale022
# ale022    1.716559e-79
# dtype: float64
# ale023
# ale023    6.779743e-113
# dtype: float64
# ale026
# ale026    2.610573e-41
# dtype: float64
# ale071
# ale071    1.189267e-152
# dtype: float64
# ale074
# ale074    0.510383
# dtype: float64
# ale075
# ale075    3.513019e-10
# dtype: float64
# ale076
# ale076    0.567016
# dtype: float64
# ale077
# ale077    0.930678
# dtype: float64
# ale078
# ale078    2.012564e-15
# dtype: float64
# ale080
# ale080    0.116252
# dtype: float64
# ale081
# ale081    9.362433e-18
# dtype: float64
# ale084
# ale084    2.141892e-17
# dtype: float64
# ale403
# ale403    2.421889e-65
# dtype: float64
# ale501
# C(ale501)[T.1.0]      6.532356e-46
# C(ale501)[T.120.0]    1.279593e-03
# C(ale501)[T.150.0]    3.523145e-01
# C(ale501)[T.180.0]    1.695798e-03
# C(ale501)[T.30.0]     2.640199e-16
# C(ale501)[T.34.0]     3.869645e-04
# C(ale501)[T.400.0]    1.660535e-47
# C(ale501)[T.60.0]     1.828229e-03
# C(ale501)[T.90.0]     1.534062e-02
# dtype: float64
# ale502
# C(ale502)[T.1.0]      1.223383e-43
# C(ale502)[T.120.0]    5.568452e-01
# C(ale502)[T.180.0]    7.555904e-01
# C(ale502)[T.30.0]     1.348928e-02
# C(ale502)[T.34.0]     2.093888e-01
# C(ale502)[T.400.0]    2.156892e-04
# C(ale502)[T.60.0]     4.944315e-01
# C(ale502)[T.90.0]     7.899443e-01
# dtype: float64
# ale503
# C(ale503)[T.1.0]      1.563936e-44
# C(ale503)[T.120.0]    1.186253e-01
# C(ale503)[T.150.0]    6.735742e-01
# C(ale503)[T.180.0]    5.753406e-01
# C(ale503)[T.30.0]     7.747765e-06
# C(ale503)[T.34.0]     9.630875e-01
# C(ale503)[T.400.0]    3.473212e-10
# C(ale503)[T.60.0]     3.584901e-01
# C(ale503)[T.90.0]     1.891241e-01
# dtype: float64
# ale601
# C(ale601)[T.1.0]      4.676452e-36
# C(ale601)[T.120.0]    8.730502e-01
# C(ale601)[T.150.0]    7.548260e-01
# C(ale601)[T.180.0]    9.732724e-02
# C(ale601)[T.30.0]     7.037271e-01
# C(ale601)[T.34.0]     3.229644e-01
# C(ale601)[T.60.0]     6.375418e-01
# C(ale601)[T.90.0]     7.542783e-01
# dtype: float64
# ale720
# ale720    1.544694e-10
# dtype: float64
# ale724
# ale724    0.433171
# dtype: float64
# ale740
# ale740    1.054680e-17
# dtype: float64
# ale801
# ale801    2.378796e-60
# dtype: float64
# ale804
# ale804    6.045941e-47
# dtype: float64
# ale901
# ale901    1.684047e-48
# dtype: float64
# ale903
# ale903    0.943389
# dtype: float64
# ale904
# ale904    0.02941
# dtype: float64
# ale905
# ale905    0.000384
# dtype: float64
# ale906
# ale906    0.000155
# dtype: float64
# ale908
# ale908    5.553443e-34
# dtype: float64
# all074
# all074    0.26209
# dtype: float64
# all075
# all075    6.336077e-38
# dtype: float64
# all076
# all076    0.887052
# dtype: float64
# all077
# all077    0.034647
# dtype: float64
# all078
# all078    3.099140e-47
# dtype: float64
# all080
# all080    0.973786
# dtype: float64
# all084
# all084    1.517988e-50
# dtype: float64
# all085
# all085    0.000506
# dtype: float64
# all086
# all086    6.893052e-08
# dtype: float64
# all091
# all091    2.947192e-55
# dtype: float64
# all092
# all092    2.836365e-51
# dtype: float64
# all103
# all103    0.398116
# dtype: float64
# all104
# all104    0.365577
# dtype: float64
# all105
# all105    0.770604
# dtype: float64
# all107
# all107    0.12596
# dtype: float64
# all109
# all109    0.104799
# dtype: float64
# all110
# all110    0.019488
# dtype: float64
# all111
# all111    0.008824
# dtype: float64
# all112
# all112    0.191048
# dtype: float64
# all113
# all113    0.26641
# dtype: float64
# all114
# all114    0.003622
# dtype: float64
# all115
# all115    0.00002
# dtype: float64
# all116
# all116    0.013602
# dtype: float64
# all117
# all117    0.069821
# dtype: float64
# all119
# all119    0.962218
# dtype: float64
# all121
# all121    0.256822
# dtype: float64
# all122
# all122    0.034558
# dtype: float64
# all123
# all123    0.017864
# dtype: float64
# all125
# all125    0.000524
# dtype: float64
# all128
# all128    4.408508e-12
# dtype: float64
# all129
# all129    1.659369e-12
# dtype: float64
# all131
# all131    0.366178
# dtype: float64
# all143
# all143    4.299581e-08
# dtype: float64
# all152
# all152    0.000651
# dtype: float64
# all153
# all153    2.734477e-41
# dtype: float64
# all602
# C(all602)[T.1.0]      3.561405e-10
# C(all602)[T.120.0]    8.185571e-01
# C(all602)[T.150.0]    8.100910e-01
# C(all602)[T.180.0]    8.390478e-01
# C(all602)[T.30.0]     7.835275e-01
# C(all602)[T.34.0]     6.840948e-01
# C(all602)[T.60.0]     1.094385e-01
# C(all602)[T.90.0]     2.625748e-01
# dtype: float64
# all724
# all724    0.076356
# dtype: float64
# all760
# all760    9.407103e-31
# dtype: float64
# all907
# all907    2.971738e-192
# dtype: float64
# aut001
# aut001    1.524201e-155
# dtype: float64
# aut071
# aut071    1.737529e-152
# dtype: float64
# aut720
# aut720    3.255471e-09
# dtype: float64
# bac023
# bac023    2.274545e-07
# dtype: float64
# bac037
# bac037    0.000003
# dtype: float64
# bac074
# bac074    0.074151
# dtype: float64
# bac075
# bac075    2.562148e-34
# dtype: float64
# bac076
# bac076    0.326948
# dtype: float64
# bac077
# bac077    0.205942
# dtype: float64
# bac078
# bac078    3.097197e-43
# dtype: float64
# bac080
# bac080    0.634361
# dtype: float64
# bac801
# bac801    2.375421e-33
# dtype: float64
# bac903
# bac903    9.336460e-16
# dtype: float64
# bac904
# bac904    5.643418e-29
# dtype: float64
# bac905
# bac905    3.886652e-31
# dtype: float64
# bac906
# bac906    7.624714e-36
# dtype: float64
# bnk001
# bnk001    4.434906e-103
# dtype: float64
# cap026
# cap026    1.560645e-08
# dtype: float64
# cap801
# cap801    6.145915e-36
# dtype: float64
# cru001
# cru001    8.087524e-90
# dtype: float64
# fil001
# fil001    4.064403e-68
# dtype: float64
# fil023
# fil023    3.159497e-57
# dtype: float64
# fin001
# fin001    1.933684e-83
# dtype: float64
# fin026
# fin026    0.004585
# dtype: float64
# fin801
# fin801    5.297201e-65
# dtype: float64
# iln001
# iln001    8.296554e-144
# dtype: float64
# iln005
# iln005    3.287038e-144
# dtype: float64
# iln006
# iln006    2.682941e-12
# dtype: float64
# iln026
# iln026    2.450247e-12
# dtype: float64
# iln064
# iln064    0.685098
# dtype: float64
# iln067
# iln067    0.602005
# dtype: float64
# iln074
# iln074    0.42526
# dtype: float64
# iln076
# iln076    0.177786
# dtype: float64
# iln077
# iln077    0.165223
# dtype: float64
# iln078
# iln078    4.608720e-11
# dtype: float64
# iln080
# iln080    0.730281
# dtype: float64
# iln084
# iln084    5.730008e-17
# dtype: float64
# iln085
# iln085    0.000741
# dtype: float64
# iln086
# iln086    0.050231
# dtype: float64
# iln103
# iln103    0.51447
# dtype: float64
# iln104
# iln104    0.058809
# dtype: float64
# iln105
# iln105    0.501231
# dtype: float64
# iln106
# iln106    0.367493
# dtype: float64
# iln107
# iln107    0.961408
# dtype: float64
# iln108
# iln108    0.938664
# dtype: float64
# iln109
# iln109    0.179541
# dtype: float64
# iln110
# iln110    0.31973
# dtype: float64
# iln111
# iln111    0.321737
# dtype: float64
# iln113
# iln113    0.894341
# dtype: float64
# iln114
# iln114    0.007222
# dtype: float64
# iln115
# iln115    0.373442
# dtype: float64
# iln116
# iln116    0.305717
# dtype: float64
# iln117
# iln117    0.194151
# dtype: float64
# iln118
# iln118    0.021648
# dtype: float64
# iln119
# iln119    0.625327
# dtype: float64
# iln122
# iln122    0.084248
# dtype: float64
# iln124
# iln124    0.059687
# dtype: float64
# iln125
# iln125    0.623034
# dtype: float64
# iln128
# iln128    0.074698
# dtype: float64
# iln129
# iln129    0.11374
# dtype: float64
# iln130
# iln130    0.000136
# dtype: float64
# iln302
# iln302    4.296652e-17
# dtype: float64
# iln501
# C(iln501)[T.1.0]      3.992631e-17
# C(iln501)[T.120.0]    1.685360e-05
# C(iln501)[T.150.0]    1.067641e-02
# C(iln501)[T.180.0]    1.612382e-03
# C(iln501)[T.30.0]     2.949147e-13
# C(iln501)[T.34.0]     7.069765e-04
# C(iln501)[T.400.0]    1.286057e-36
# C(iln501)[T.60.0]     2.348357e-07
# C(iln501)[T.90.0]     4.754246e-06
# dtype: float64
# iln504
# C(iln504)[T.1.0]      3.527314e-41
# C(iln504)[T.120.0]    2.230105e-01
# C(iln504)[T.150.0]    4.624788e-01
# C(iln504)[T.180.0]    8.720992e-02
# C(iln504)[T.30.0]     5.871075e-03
# C(iln504)[T.34.0]     5.823443e-01
# C(iln504)[T.400.0]    4.875174e-06
# C(iln504)[T.60.0]     2.038061e-01
# C(iln504)[T.90.0]     8.606365e-02
# dtype: float64
# iln703
# iln703    0.102794
# dtype: float64
# iln720
# iln720    5.180988e-16
# dtype: float64
# iln724
# iln724    0.154339
# dtype: float64
# iln740
# iln740    1.602828e-20
# dtype: float64
# iln801
# iln801    1.115655e-103
# dtype: float64
# iln904
# iln904    0.332067
# dtype: float64
# iln905
# iln905    0.155112
# dtype: float64
# iln906
# iln906    0.00948
# dtype: float64
# lfi801
# lfi801    1.707589e-31
# dtype: float64
# rep005
# rep005    5.831982e-130
# dtype: float64
# rep071
# rep071    2.088327e-109
# dtype: float64
# rep074
# rep074    0.759985
# dtype: float64
# rep076
# rep076    0.33588
# dtype: float64
# rep077
# rep077    0.11664
# dtype: float64
# rep078
# rep078    1.266653e-36
# dtype: float64
# rep080
# rep080    0.563328
# dtype: float64
# rep081
# rep081    1.835186e-36
# dtype: float64
# rep084
# rep084    2.795375e-40
# dtype: float64
# rep501
# C(rep501)[T.1.0]      7.381748e-71
# C(rep501)[T.120.0]    1.591857e-02
# C(rep501)[T.150.0]    8.715297e-03
# C(rep501)[T.180.0]    5.301410e-03
# C(rep501)[T.30.0]     2.206235e-07
# C(rep501)[T.34.0]     6.062946e-05
# C(rep501)[T.400.0]    1.667577e-83
# C(rep501)[T.60.0]     4.150280e-05
# C(rep501)[T.90.0]     6.051307e-01
# dtype: float64
# rep901
# rep901    1.660525e-72
# dtype: float64
# rep903
# rep903    9.882986e-11
# dtype: float64
# rep905
# rep905    9.872340e-17
# dtype: float64
# rep906
# rep906    8.930438e-22
# dtype: float64
# rev005
# rev005    4.218355e-61
# dtype: float64
# rev023
# rev023    5.259265e-17
# dtype: float64
# rev044
# rev044    8.257689e-27
# dtype: float64
# rev064
# rev064    0.426379
# dtype: float64
# rev067
# rev067    0.204537
# dtype: float64
# rev074
# rev074    0.058216
# dtype: float64
# rev075
# rev075    1.171696e-29
# dtype: float64
# rev076
# rev076    0.267247
# dtype: float64
# rev077
# rev077    0.191391
# dtype: float64
# rev078
# rev078    4.932943e-40
# dtype: float64
# rev080
# rev080    0.997692
# dtype: float64
# rev084
# rev084    1.969718e-42
# dtype: float64
# rev085
# rev085    0.000106
# dtype: float64
# rev103
# rev103    0.728346
# dtype: float64
# rev104
# rev104    0.270506
# dtype: float64
# rev105
# rev105    0.315942
# dtype: float64
# rev107
# rev107    0.343469
# dtype: float64
# rev108
# rev108    0.098413
# dtype: float64
# rev109
# rev109    0.013143
# dtype: float64
# rev110
# rev110    0.022155
# dtype: float64
# rev111
# rev111    0.009122
# dtype: float64
# rev112
# rev112    0.709222
# dtype: float64
# rev113
# rev113    0.69425
# dtype: float64
# rev114
# rev114    0.000661
# dtype: float64
# rev116
# rev116    0.017553
# dtype: float64
# rev117
# rev117    0.007223
# dtype: float64
# rev118
# rev118    0.000517
# dtype: float64
# rev119
# rev119    0.835821
# dtype: float64
# rev122
# rev122    0.597321
# dtype: float64
# rev124
# rev124    0.022854
# dtype: float64
# rev127
# rev127    0.00002
# dtype: float64
# rev128
# rev128    7.269623e-13
# dtype: float64
# rev129
# rev129    5.690458e-14
# dtype: float64
# rev404
# rev404    0.20297
# dtype: float64
# rev501
# C(rev501)[T.1.0]      0.174641
# C(rev501)[T.120.0]    0.185944
# C(rev501)[T.150.0]    0.169999
# C(rev501)[T.180.0]    0.166225
# C(rev501)[T.30.0]     0.180931
# C(rev501)[T.34.0]     0.180279
# C(rev501)[T.400.0]    0.257266
# C(rev501)[T.60.0]     0.191172
# C(rev501)[T.90.0]     0.154054
# dtype: float64
# rev504
# C(rev504)[T.1.0]      0.000041
# C(rev504)[T.120.0]    0.573909
# C(rev504)[T.150.0]    0.012162
# C(rev504)[T.180.0]    0.465655
# C(rev504)[T.30.0]     0.412927
# C(rev504)[T.34.0]     0.915423
# C(rev504)[T.400.0]    0.000054
# C(rev504)[T.60.0]     0.565858
# C(rev504)[T.90.0]     0.955882
# dtype: float64
# rev724
# rev724    0.423388
# dtype: float64
# rev903
# rev903    8.326328e-12
# dtype: float64
# rev905
# rev905    6.039463e-28
# dtype: float64
# rev906
# rev906    1.054653e-33
# dtype: float64
# rti026
# rti026    0.010393
# dtype: float64
# rtl005
# rtl005    1.074922e-23
# dtype: float64
# rtl026
# rtl026    0.869556
# dtype: float64
# rtl071
# rtl071    5.522825e-23
# dtype: float64
# rtl074
# rtl074    0.239956
# dtype: float64
# rtl075
# rtl075    0.000554
# dtype: float64
# rtl076
# rtl076    0.32518
# dtype: float64
# rtl077
# rtl077    0.867307
# dtype: float64
# rtl078
# rtl078    7.967638e-08
# dtype: float64
# rtl080
# rtl080    0.800111
# dtype: float64
# rtl081
# rtl081    1.727892e-08
# dtype: float64
# rtl084
# rtl084    3.054782e-09
# dtype: float64
# rtl501
# C(rtl501)[T.1.0]      5.033808e-04
# C(rtl501)[T.120.0]    3.431402e-01
# C(rtl501)[T.150.0]    6.621174e-01
# C(rtl501)[T.180.0]    7.703997e-01
# C(rtl501)[T.30.0]     2.875402e-02
# C(rtl501)[T.34.0]     7.644338e-01
# C(rtl501)[T.400.0]    1.917334e-19
# C(rtl501)[T.60.0]     3.934012e-02
# C(rtl501)[T.90.0]     5.519973e-01
# dtype: float64
# rtl502
# C(rtl502)[T.1.0]      0.110689
# C(rtl502)[T.120.0]    0.206409
# C(rtl502)[T.150.0]    0.418067
# C(rtl502)[T.180.0]    0.592461
# C(rtl502)[T.30.0]     0.200883
# C(rtl502)[T.34.0]     0.318246
# C(rtl502)[T.400.0]    0.000040
# C(rtl502)[T.60.0]     0.185967
# C(rtl502)[T.90.0]     0.758661
# dtype: float64
# rtl503
# C(rtl503)[T.1.0]      0.252799
# C(rtl503)[T.120.0]    0.504891
# C(rtl503)[T.150.0]    0.980317
# C(rtl503)[T.180.0]    0.729999
# C(rtl503)[T.30.0]     0.906906
# C(rtl503)[T.34.0]     0.791976
# C(rtl503)[T.400.0]    0.000002
# C(rtl503)[T.60.0]     0.833136
# C(rtl503)[T.90.0]     0.834598
# dtype: float64
# rtl901
# rtl901    0.000807
# dtype: float64
# rtl903
# rtl903    0.211316
# dtype: float64
# rtl904
# rtl904    0.000569
# dtype: float64
# rtl905
# rtl905    0.000027
# dtype: float64
# rtl906
# rtl906    0.000003
# dtype: float64
# rtl908
# rtl908    0.097554
# dtype: float64
# rtr007
# rtr007    0.37256
# dtype: float64
# rtr022
# rtr022    7.198082e-11
# dtype: float64
# rtr023
# rtr023    1.226331e-13
# dtype: float64
# rtr028
# rtr028    0.419837
# dtype: float64
# rtr031
# rtr031    1.465365e-20
# dtype: float64
# rtr035
# rtr035    3.978583e-25
# dtype: float64
# rtr044
# rtr044    7.692061e-10
# dtype: float64
# rtr071
# rtr071    6.780743e-24
# dtype: float64
# rtr074
# rtr074    0.281565
# dtype: float64
# rtr075
# rtr075    0.000355
# dtype: float64
# rtr076
# rtr076    0.379739
# dtype: float64
# rtr077
# rtr077    0.823646
# dtype: float64
# rtr078
# rtr078    5.060095e-08
# dtype: float64
# rtr080
# rtr080    0.727071
# dtype: float64
# rtr081
# rtr081    1.164679e-08
# dtype: float64
# rtr084
# rtr084    1.731830e-09
# dtype: float64
# rtr584
# rtr584    0.032921
# dtype: float64
# rtr585
# rtr585    0.001921
# dtype: float64
# rtr589
# rtr589    0.451567
# dtype: float64
# rtr590
# rtr590    0.456088
# dtype: float64
# rtr601
# C(rtr601)[T.1.0]      0.557791
# C(rtr601)[T.120.0]    0.759923
# C(rtr601)[T.180.0]    0.863341
# C(rtr601)[T.30.0]     0.656094
# C(rtr601)[T.34.0]     0.311205
# C(rtr601)[T.60.0]     0.794583
# C(rtr601)[T.90.0]     0.677621
# dtype: float64
# rtr751
# rtr751    1.801855e-17
# dtype: float64
# rtr752
# rtr752    2.523135e-25
# dtype: float64
# rtr901
# rtr901    0.000402
# dtype: float64
# rtr904
# rtr904    0.000365
# dtype: float64
# rtr905
# rtr905    0.000022
# dtype: float64
# rtr906
# rtr906    0.000001
# dtype: float64
# rtr908
# rtr908    0.133885
# dtype: float64
# monthly_debt
# monthly_debt    3.819508e-31
# dtype: float64
# current_delinquencies
# current_delinquencies    7.077416e-12
# dtype: float64
# delinquencies_last7_years
# delinquencies_last7_years    3.960504e-52
# dtype: float64
# public_records_last10_years
# public_records_last10_years    0.028735
# dtype: float64
# public_records_last12_months
# public_records_last12_months    6.824131e-11
# dtype: float64
# credit_lines_last7_years
# credit_lines_last7_years    0.0
# dtype: float64
# inquiries_last6_months
# inquiries_last6_months    1.303487e-151
# dtype: float64
# amount_delinquent
# amount_delinquent    0.005324
# dtype: float64
# current_credit_lines
# current_credit_lines    4.801539e-54
# dtype: float64
# open_credit_lines
# open_credit_lines    5.966026e-44
# dtype: float64
# bankcard_utilization
# bankcard_utilization    1.796454e-09
# dtype: float64
# total_open_revolving_accounts
# total_open_revolving_accounts    1.180129e-07
# dtype: float64
# installment_balance
# installment_balance    2.353569e-15
# dtype: float64
# real_estate_balance
# real_estate_balance    7.128418e-59
# dtype: float64
# revolving_balance
# revolving_balance    0.546247
# dtype: float64
# real_estate_payment
# real_estate_payment    5.384945e-19
# dtype: float64
# revolving_available_percent
# revolving_available_percent    0.360665
# dtype: float64
# total_inquiries
# total_inquiries    6.519677e-140
# dtype: float64
# total_trade_items
# total_trade_items    0.0
# dtype: float64
# satisfactory_accounts
# satisfactory_accounts    0.0
# dtype: float64
# now_delinquent_derog
# now_delinquent_derog    7.454932e-12
# dtype: float64
# was_delinquent_derog
# C(was_delinquent_derog)[T.1.0]     4.085812e-01
# C(was_delinquent_derog)[T.10.0]    8.658064e-14
# C(was_delinquent_derog)[T.11.0]    2.513874e-09
# C(was_delinquent_derog)[T.12.0]    1.516235e-10
# C(was_delinquent_derog)[T.13.0]    1.284520e-06
# C(was_delinquent_derog)[T.14.0]    2.810254e-09
# C(was_delinquent_derog)[T.15.0]    3.997664e-07
# C(was_delinquent_derog)[T.16.0]    3.324224e-05
# C(was_delinquent_derog)[T.17.0]    3.010463e-04
# C(was_delinquent_derog)[T.18.0]    1.971875e-03
# C(was_delinquent_derog)[T.19.0]    8.303307e-03
# C(was_delinquent_derog)[T.2.0]     4.336967e-01
# C(was_delinquent_derog)[T.20.0]    4.775211e-01
# C(was_delinquent_derog)[T.21.0]    4.730906e-01
# C(was_delinquent_derog)[T.22.0]    7.373995e-03
# C(was_delinquent_derog)[T.23.0]    2.355727e-01
# C(was_delinquent_derog)[T.24.0]    3.069823e-01
# C(was_delinquent_derog)[T.25.0]    8.753621e-01
# C(was_delinquent_derog)[T.26.0]    1.440251e-01
# C(was_delinquent_derog)[T.27.0]    7.722694e-01
# C(was_delinquent_derog)[T.28.0]    6.811776e-01
# C(was_delinquent_derog)[T.29.0]    3.194208e-01
# C(was_delinquent_derog)[T.3.0]     7.382336e-01
# C(was_delinquent_derog)[T.30.0]    8.647003e-01
# C(was_delinquent_derog)[T.31.0]    1.626605e-01
# C(was_delinquent_derog)[T.32.0]    3.472542e-01
# C(was_delinquent_derog)[T.33.0]    6.594070e-01
# C(was_delinquent_derog)[T.36.0]    6.725533e-01
# C(was_delinquent_derog)[T.37.0]    3.871428e-01
# C(was_delinquent_derog)[T.38.0]    5.184455e-01
# C(was_delinquent_derog)[T.4.0]     1.059074e-01
# C(was_delinquent_derog)[T.5.0]     3.650275e-01
# C(was_delinquent_derog)[T.6.0]     4.461327e-02
# C(was_delinquent_derog)[T.7.0]     1.914468e-06
# C(was_delinquent_derog)[T.8.0]     4.992734e-11
# C(was_delinquent_derog)[T.9.0]     5.518428e-16
# dtype: float64
# delinquencies_over30_days
# delinquencies_over30_days    1.204053e-11
# dtype: float64
# delinquencies_over60_days
# delinquencies_over60_days    1.802229e-40
# dtype: float64
# delinquencies_over90_days
# delinquencies_over90_days    3.583340e-52
# dtype: float64
# is_homeowner
# C(is_homeowner)[T.True]    4.285614e-68
# dtype: float64
# investment_typeid
# C(investment_typeid)[T.2.0]    1.552820e-74
# C(investment_typeid)[T.3.0]    1.648978e-20
# dtype: float64
# investment_type_description
# C(investment_type_description)[T.Whole]    0.371497
# dtype: float64
